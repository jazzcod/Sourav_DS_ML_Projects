# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
ds_wine=pd.read_csv("Wine.csv",header=None)
ds_wine.columns=["class","Alcohol","Malic acid","Ash","Alcalinity of ash","Magnesium","Total phenols","Flavanoids",
                 "Nonflavanoid phenols","Proanthocyanins","Color intensity","Hue","OD280/OD315 of diluted wines","Proline"]
ds_wine
# Out:
#      class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# 1             2.65        2.76                  0.26             1.28
# 2             2.80        3.24                  0.30             2.81
# 3             3.85        3.49                  0.24             2.18
# 4             2.80        2.69                  0.39             1.82
# ..             ...         ...                   ...              ...
# 173           1.68        0.61                  0.52             1.06
# 174           1.80        0.75                  0.43             1.41
# 175           1.59        0.69                  0.43             1.35
# 176           1.65        0.68                  0.53             1.46
# 177           2.05        0.76                  0.56             1.35
#
#      Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0               5.64  1.04                          3.92     1065
# 1               4.38  1.05                          3.40     1050
# 2               5.68  1.03                          3.17     1185
# 3               7.80  0.86                          3.45     1480
# 4               4.32  1.04                          2.93      735
# ..               ...   ...                           ...      ...
# 173             7.70  0.64                          1.74      740
# 174             7.30  0.70                          1.56      750
# 175            10.20  0.59                          1.56      835
# 176             9.30  0.60                          1.62      840
# 177             9.20  0.61                          1.60      560
#
# [178 rows x 14 columns]

# %% [markdown]
# ### Checking Null Values

# %%
ds_wine.isnull().sum()  #no null values
# Out:
# class                           0
# Alcohol                         0
# Malic acid                      0
# Ash                             0
# Alcalinity of ash               0
# Magnesium                       0
# Total phenols                   0
# Flavanoids                      0
# Nonflavanoid phenols            0
# Proanthocyanins                 0
# Color intensity                 0
# Hue                             0
# OD280/OD315 of diluted wines    0
# Proline                         0
# dtype: int64

# %%
sns.heatmap(ds_wine.isnull())

# %% [markdown]
# ### Describing Statistics

# %%
ds_wine.describe()
# Out:
#             class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# min     70.000000       0.980000    0.340000              0.130000
# 25%     88.000000       1.742500    1.205000              0.270000
# 50%     98.000000       2.355000    2.135000              0.340000
# 75%    107.000000       2.800000    2.875000              0.437500
# max    162.000000       3.880000    5.080000              0.660000
#
#        Proanthocyanins  Color intensity         Hue  \
# count       178.000000       178.000000  178.000000
# mean          1.590899         5.058090    0.957449
# std           0.572359         2.318286    0.228572
# min           0.410000         1.280000    0.480000
# 25%           1.250000         3.220000    0.782500
# 50%           1.555000         4.690000    0.965000
# 75%           1.950000         6.200000    1.120000
# max           3.580000        13.000000    1.710000
#
#        OD280/OD315 of diluted wines      Proline
# count                    178.000000   178.000000
# mean                       2.611685   746.893258
# std                        0.709990   314.907474
# min                        1.270000   278.000000
# 25%                        1.937500   500.500000
# 50%                        2.780000   673.500000
# 75%                        3.170000   985.000000
# max                        4.000000  1680.000000

# %%
ds_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   class                         178 non-null    int64
#  1   Alcohol                       178 non-null    float64
#  2   Malic acid                    178 non-null    float64
#  3   Ash                           178 non-null    float64
#  4   Alcalinity of ash             178 non-null    float64
#  5   Magnesium                     178 non-null    int64
#  6   Total phenols                 178 non-null    float64
#  7   Flavanoids                    178 non-null    float64
#  8   Nonflavanoid phenols          178 non-null    float64
#  9   Proanthocyanins               178 non-null    float64
#  10  Color intensity               178 non-null    float64
#  11  Hue                           178 non-null    float64
#  12  OD280/OD315 of diluted wines  178 non-null    float64
#  13  Proline                       178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %% [markdown]
# ### Checking Correlation

# %%
ds_wine.corr()
# Out:
#                                  class   Alcohol  Malic acid       Ash  \
# class                         1.000000 -0.328222    0.437776 -0.049643
# Alcohol                      -0.328222  1.000000    0.094397  0.211545
# Malic acid                    0.437776  0.094397    1.000000  0.164045
# Ash                          -0.049643  0.211545    0.164045  1.000000
# Alcalinity of ash             0.517859 -0.310235    0.288500  0.443367
# Magnesium                    -0.209179  0.270798   -0.054575  0.286587
# Total phenols                -0.719163  0.289101   -0.335167  0.128980
# Flavanoids                   -0.847498  0.236815   -0.411007  0.115077
# Nonflavanoid phenols          0.489109 -0.155929    0.292977  0.186230
# Proanthocyanins              -0.499130  0.136698   -0.220746  0.009652
# Color intensity               0.265668  0.546364    0.248985  0.258887
# Hue                          -0.617369 -0.071747   -0.561296 -0.074667
# OD280/OD315 of diluted wines -0.788230  0.072343   -0.368710  0.003911
# Proline                      -0.633717  0.643720   -0.192011  0.223626
#
#                               Alcalinity of ash  Magnesium  Total phenols  \
# class                                  0.517859  -0.209179      -0.719163
# Alcohol                               -0.310235   0.270798       0.289101
# Malic acid                             0.288500  -0.054575      -0.335167
# Ash                                    0.443367   0.286587       0.128980
# Alcalinity of ash                      1.000000  -0.083333      -0.321113
# Magnesium                             -0.083333   1.000000       0.214401
# Total phenols                         -0.321113   0.214401       1.000000
# Flavanoids                            -0.351370   0.195784       0.864564
# Nonflavanoid phenols                   0.361922  -0.256294      -0.449935
# Proanthocyanins                       -0.197327   0.236441       0.612413
# Color intensity                        0.018732   0.199950      -0.055136
# Hue                                   -0.273955   0.055398       0.433681
# OD280/OD315 of diluted wines          -0.276769   0.066004       0.699949
# Proline                               -0.440597   0.393351       0.498115
#
#                               Flavanoids  Nonflavanoid phenols  \
# class                          -0.847498              0.489109
# Alcohol                         0.236815             -0.155929
# Malic acid                     -0.411007              0.292977
# Ash                             0.115077              0.186230
# Alcalinity of ash              -0.351370              0.361922
# Magnesium                       0.195784             -0.256294
# Total phenols                   0.864564             -0.449935
# Flavanoids                      1.000000             -0.537900
# Nonflavanoid phenols           -0.537900              1.000000
# Proanthocyanins                 0.652692             -0.365845
# Color intensity                -0.172379              0.139057
# Hue                             0.543479             -0.262640
# OD280/OD315 of diluted wines    0.787194             -0.503270
# Proline                         0.494193             -0.311385
#
#                               Proanthocyanins  Color intensity       Hue  \
# class                               -0.499130         0.265668 -0.617369
# Alcohol                              0.136698         0.546364 -0.071747
# Malic acid                          -0.220746         0.248985 -0.561296
# Ash                                  0.009652         0.258887 -0.074667
# Alcalinity of ash                   -0.197327         0.018732 -0.273955
# Magnesium                            0.236441         0.199950  0.055398
# Total phenols                        0.612413        -0.055136  0.433681
# Flavanoids                           0.652692        -0.172379  0.543479
# Nonflavanoid phenols                -0.365845         0.139057 -0.262640
# Proanthocyanins                      1.000000        -0.025250  0.295544
# Color intensity                     -0.025250         1.000000 -0.521813
# Hue                                  0.295544        -0.521813  1.000000
# OD280/OD315 of diluted wines         0.519067        -0.428815  0.565468
# Proline                              0.330417         0.316100  0.236183
#
#                               OD280/OD315 of diluted wines   Proline
# class                                            -0.788230 -0.633717
# Alcohol                                           0.072343  0.643720
# Malic acid                                       -0.368710 -0.192011
# Ash                                               0.003911  0.223626
# Alcalinity of ash                                -0.276769 -0.440597
# Magnesium                                         0.066004  0.393351
# Total phenols                                     0.699949  0.498115
# Flavanoids                                        0.787194  0.494193
# Nonflavanoid phenols                             -0.503270 -0.311385
# Proanthocyanins                                   0.519067  0.330417
# Color intensity                                  -0.428815  0.316100
# Hue                                               0.565468  0.236183
# OD280/OD315 of diluted wines                      1.000000  0.312761
# Proline                                           0.312761  1.000000

# %%
corr_hmap=ds_wine.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %% [markdown]
# ### Removing Outliers

# %%
from scipy.stats import zscore
z_score=abs(zscore(ds_wine))
print(ds_wine.shape)
ds_wine_final=ds_wine.loc[(z_score<3).all(axis=1)]
print(ds_wine_final.shape)
# Out:
# (178, 14)
# (168, 14)

# %%
ds_wine.plot(kind="box",subplots=True,layout=(4,5))
# Out:
# class                               AxesSubplot(0.125,0.71587;0.133621x0.16413)
# Alcohol                          AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# Malic acid                        AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# Ash                              AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# Alcalinity of ash                AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# Magnesium                          AxesSubplot(0.125,0.518913;0.133621x0.16413)
# Total phenols                   AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# Flavanoids                       AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# Nonflavanoid phenols            AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# Proanthocyanins                 AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# Color intensity                    AxesSubplot(0.125,0.321957;0.133621x0.16413)
# Hue                             AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# OD280/OD315 of diluted wines     AxesSubplot(0.44569,0.321957;0.133621x0.16413)
# Proline                         AxesSubplot(0.606034,0.321957;0.133621x0.16413)
# dtype: object

# %% [markdown]
# ### Checking Skewness

# %%
ds_wine_final.skew()
# Out:
# class                           0.117053
# Alcohol                        -0.028038
# Malic acid                      0.966253
# Ash                            -0.250438
# Alcalinity of ash               0.104774
# Magnesium                       0.566522
# Total phenols                   0.132108
# Flavanoids                     -0.077205
# Nonflavanoid phenols            0.481810
# Proanthocyanins                 0.360217
# Color intensity                 0.732580
# Hue                            -0.137430
# OD280/OD315 of diluted wines   -0.282514
# Proline                         0.744773
# dtype: float64

# %% [markdown]
# ### Plotting Distribution

# %%
for i in ds_wine.columns:
    plt.figure()
    sns.distplot(ds_wine[i])

# %% [markdown]
# ### Log Transformation

# %%
for col in ds_wine_final:                   
    if ds_wine_final.skew().loc[col]>.55:
        ds_wine_final[col]=np.log1p(ds_wine_final[col])

# %%
ds_wine_final.skew()
# Out:
# class                           0.117053
# Alcohol                        -0.028038
# Malic acid                      0.481235
# Ash                            -0.250438
# Alcalinity of ash               0.104774
# Magnesium                       0.260440
# Total phenols                   0.132108
# Flavanoids                     -0.077205
# Nonflavanoid phenols            0.481810
# Proanthocyanins                 0.360217
# Color intensity                 0.012720
# Hue                            -0.137430
# OD280/OD315 of diluted wines   -0.282514
# Proline                         0.071873
# dtype: float64

# %%
for i in ds_wine_final.columns:
    plt.figure()
    sns.distplot(ds_wine_final[i])

# %%
ds_wine_final
# Out:
#      class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23    0.996949  2.43               15.6   4.852030
# 1        1    13.20    1.022451  2.14               11.2   4.615121
# 2        1    13.16    1.211941  2.67               18.6   4.624973
# 3        1    14.37    1.081805  2.50               16.8   4.736198
# 4        1    13.24    1.278152  2.87               21.0   4.779123
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71    1.894617  2.45               20.5   4.564348
# 174      3    13.40    1.591274  2.48               23.0   4.634729
# 175      3    13.27    1.663926  2.26               20.0   4.795791
# 176      3    13.17    1.278152  2.37               20.0   4.795791
# 177      3    14.13    1.629241  2.74               24.5   4.574711
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# 1             2.65        2.76                  0.26             1.28
# 2             2.80        3.24                  0.30             2.81
# 3             3.85        3.49                  0.24             2.18
# 4             2.80        2.69                  0.39             1.82
# ..             ...         ...                   ...              ...
# 173           1.68        0.61                  0.52             1.06
# 174           1.80        0.75                  0.43             1.41
# 175           1.59        0.69                  0.43             1.35
# 176           1.65        0.68                  0.53             1.46
# 177           2.05        0.76                  0.56             1.35
#
#      Color intensity   Hue  OD280/OD315 of diluted wines   Proline
# 0           1.893112  1.04                          3.92  6.971669
# 1           1.682688  1.05                          3.40  6.957497
# 2           1.899118  1.03                          3.17  7.078342
# 3           2.174752  0.86                          3.45  7.300473
# 4           1.671473  1.04                          2.93  6.601230
# ..               ...   ...                           ...       ...
# 173         2.163323  0.64                          1.74  6.608001
# 174         2.116256  0.70                          1.56  6.621406
# 175         2.415914  0.59                          1.56  6.728629
# 176         2.332144  0.60                          1.62  6.734592
# 177         2.322388  0.61                          1.60  6.329721
#
# [168 rows x 14 columns]

# %% [markdown]
# ### Bivariate Analysis

# %%
for i in ds_wine_final.columns:
    sns.barplot(y=ds_wine_final[i],x='class',data=ds_wine_final)
    plt.show()

# %% [markdown]
# ### Seperating Target and Input Variables

# %%
x=ds_wine_final.iloc[:,1:]
x
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0      14.23    0.996949  2.43               15.6   4.852030           2.80
# 1      13.20    1.022451  2.14               11.2   4.615121           2.65
# 2      13.16    1.211941  2.67               18.6   4.624973           2.80
# 3      14.37    1.081805  2.50               16.8   4.736198           3.85
# 4      13.24    1.278152  2.87               21.0   4.779123           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71    1.894617  2.45               20.5   4.564348           1.68
# 174    13.40    1.591274  2.48               23.0   4.634729           1.80
# 175    13.27    1.663926  2.26               20.0   4.795791           1.59
# 176    13.17    1.278152  2.37               20.0   4.795791           1.65
# 177    14.13    1.629241  2.74               24.5   4.574711           2.05
#
#      Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0          3.06                  0.28             2.29         1.893112  1.04
# 1          2.76                  0.26             1.28         1.682688  1.05
# 2          3.24                  0.30             2.81         1.899118  1.03
# 3          3.49                  0.24             2.18         2.174752  0.86
# 4          2.69                  0.39             1.82         1.671473  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06         2.163323  0.64
# 174        0.75                  0.43             1.41         2.116256  0.70
# 175        0.69                  0.43             1.35         2.415914  0.59
# 176        0.68                  0.53             1.46         2.332144  0.60
# 177        0.76                  0.56             1.35         2.322388  0.61
#
#      OD280/OD315 of diluted wines   Proline
# 0                            3.92  6.971669
# 1                            3.40  6.957497
# 2                            3.17  7.078342
# 3                            3.45  7.300473
# 4                            2.93  6.601230
# ..                            ...       ...
# 173                          1.74  6.608001
# 174                          1.56  6.621406
# 175                          1.56  6.728629
# 176                          1.62  6.734592
# 177                          1.60  6.329721
#
# [168 rows x 13 columns]

# %%
y=ds_wine_final.iloc[:,0]
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: class, Length: 168, dtype: int64

# %% [markdown]
# ### Scaling the Input Variables

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.51353876, -0.52878514,  0.25063712, ...,  0.40376609,
#          1.8574532 ,  1.0383251 ],
#        [ 0.21092886, -0.44528371, -0.94535119, ...,  0.44924866,
#          1.12760518,  1.00436113],
#        [ 0.16034207,  0.17515818,  1.24042055, ...,  0.35828352,
#          0.80478778,  1.29398645],
#        ...,
#        [ 0.29945574,  1.65508026, -0.45045947, ..., -1.64294949,
#         -1.454934  ,  0.45583517],
#        [ 0.17298876,  0.39195173,  0.00319127, ..., -1.59746692,
#         -1.37072076,  0.4701267 ],
#        [ 1.38707178,  1.54151032,  1.52910738, ..., -1.55198436,
#         -1.39879184, -0.50022034]])

# %% [markdown]
# ### Splitting the Input and the Output Variable

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=45,stratify=y)

# %% [markdown]
# ### Importing Metrics

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# %% [markdown]
# ### Binarizing the Target Variables and Defining Multiclass function

# %%
from sklearn.preprocessing import LabelBinarizer
def multiclass_roc_auc_score(y_test,pred, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_test)
    y_test = lb.transform(y_test)
    pred = lb.transform(pred)
    return roc_auc_score(y_test, pred, average=average)

# %% [markdown]
# ### Machine Learning

# %% [markdown]
# #### K Nearest Neighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
pred=knn.predict(x_test)
print("Accuracy score is:",accuracy_score(y_test,pred))
print("\n")
print("Cross_val_score is:",cross_val_score(knn,x,y,cv=10).mean())
print("\n")
print("Multiclass_roc_auc_score is:",multiclass_roc_auc_score(y_test,pred))
print("\n")
print("Classification_report")
print(classification_report(y_test,pred))
print("\n")
print("Confusion_matirx")
cm=confusion_matrix(y_test,pred)
plt.figure(figsize=(12,8))
sns.heatmap(cm,annot=True)
print(cm)
# Out:
# Accuracy score is: 0.9705882352941176
#
#
# Cross_val_score is: 0.9525735294117647
#
#
# Multiclass_roc_auc_score is: 0.9796037296037295
#
#
# Classification_report
#               precision    recall  f1-score   support
#
#            1       0.92      1.00      0.96        12
#            2       1.00      0.92      0.96        13
#            3       1.00      1.00      1.00         9
#
#     accuracy                           0.97        34
#    macro avg       0.97      0.97      0.97        34
# weighted avg       0.97      0.97      0.97        34
#
#
#
# Confusion_matirx
# [[12  0  0]
#  [ 1 12  0]
#  [ 0  0  9]]

# %% [markdown]
# #### SVC

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
pred=svc.predict(x_test)
print("Accuracy score is:",accuracy_score(y_test,pred))
print("\n")
print("Cross_val_score is:",cross_val_score(svc,x,y,cv=10).mean())
print("\n")
print("Multiclass_roc_auc_score is:",multiclass_roc_auc_score(y_test,pred))
print("\n")
print("Classification_report")
print(classification_report(y_test,pred))
print("\n")
print("Confusion_matirx")
cm=confusion_matrix(y_test,pred)
plt.figure(figsize=(12,8))
sns.heatmap(cm,annot=True)
print(cm)
# Out:
# Accuracy score is: 1.0
#
#
# Cross_val_score is: 0.9882352941176471
#
#
# Multiclass_roc_auc_score is: 1.0
#
#
# Classification_report
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00        13
#            3       1.00      1.00      1.00         9
#
#     accuracy                           1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34
#
#
#
# Confusion_matirx
# [[12  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
pred=lr.predict(x_test)
print("Accuracy score is:",accuracy_score(y_test,pred))
print("\n")
print("Cross_val_score is:",cross_val_score(svc,x,y,cv=10).mean())
print("\n")
print("Multiclass_roc_auc_score is:",multiclass_roc_auc_score(y_test,pred))
print("\n")
print("Classification_report")
print(classification_report(y_test,pred))
print("\n")
print("Confusion_matirx")
cm=confusion_matrix(y_test,pred)
plt.figure(figsize=(12,8))
sns.heatmap(cm,annot=True)
print(cm)
# Out:
# Accuracy score is: 1.0
#
#
# Cross_val_score is: 0.9882352941176471
#
#
# Multiclass_roc_auc_score is: 1.0
#
#
# Classification_report
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00        13
#            3       1.00      1.00      1.00         9
#
#     accuracy                           1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34
#
#
#
# Confusion_matirx
# [[12  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]

# %% [markdown]
# #### DecisionTree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
pred=dtc.predict(x_test)
print("Accuracy score is:",accuracy_score(y_test,pred))
print("\n")
print("Cross_val_score is:",cross_val_score(svc,x,y,cv=10).mean())
print("\n")
print("Multiclass_roc_auc_score is:",multiclass_roc_auc_score(y_test,pred))
print("\n")
print("Classification_report")
print(classification_report(y_test,pred))
print("\n")
print("Confusion_matirx")
cm=confusion_matrix(y_test,pred)
plt.figure(figsize=(12,8))
sns.heatmap(cm,annot=True)
print(cm)
# Out:
# Accuracy score is: 0.9411764705882353
#
#
# Cross_val_score is: 0.9882352941176471
#
#
# Multiclass_roc_auc_score is: 0.9592074592074592
#
#
# Classification_report
#               precision    recall  f1-score   support
#
#            1       0.86      1.00      0.92        12
#            2       1.00      0.85      0.92        13
#            3       1.00      1.00      1.00         9
#
#     accuracy                           0.94        34
#    macro avg       0.95      0.95      0.95        34
# weighted avg       0.95      0.94      0.94        34
#
#
#
# Confusion_matirx
# [[12  0  0]
#  [ 2 11  0]
#  [ 0  0  9]]

# %% [markdown]
# #### Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(x_train,y_train)
pred=gnb.predict(x_test)
print("Accuracy score is:",accuracy_score(y_test,pred))
print("\n")
print("Cross_val_score is:",cross_val_score(svc,x,y,cv=10).mean())
print("\n")
print("Multiclass_roc_auc_score is:",multiclass_roc_auc_score(y_test,pred))
print("\n")
print("Classification_report")
print(classification_report(y_test,pred))
print("\n")
print("Confusion_matirx")
cm=confusion_matrix(y_test,pred)
plt.figure(figsize=(12,8))
sns.heatmap(cm,annot=True)
print(cm)
# Out:
# Accuracy score is: 1.0
#
#
# Cross_val_score is: 0.9882352941176471
#
#
# Multiclass_roc_auc_score is: 1.0
#
#
# Classification_report
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00        13
#            3       1.00      1.00      1.00         9
#
#     accuracy                           1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34
#
#
#
# Confusion_matirx
# [[12  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]

# %% [markdown]
# #### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
pred=rfc.predict(x_test)
print("Accuracy score is:",accuracy_score(y_test,pred))
print("\n")
print("Cross_val_score is:",cross_val_score(svc,x,y,cv=10).mean())
print("\n")
print("Multiclass_roc_auc_score is:",multiclass_roc_auc_score(y_test,pred))
print("\n")
print("Classification_report")
print(classification_report(y_test,pred))
print("\n")
print("Confusion_matirx")
cm=confusion_matrix(y_test,pred)
plt.figure(figsize=(12,8))
sns.heatmap(cm,annot=True)
print(cm)
# Out:
# Accuracy score is: 1.0
#
#
# Cross_val_score is: 0.9882352941176471
#
#
# Multiclass_roc_auc_score is: 1.0
#
#
# Classification_report
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00        13
#            3       1.00      1.00      1.00         9
#
#     accuracy                           1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34
#
#
#
# Confusion_matirx
# [[12  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]

# %% [markdown]
# #### Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc=GradientBoostingClassifier()
gbc.fit(x_train,y_train)
pred=gbc.predict(x_test)
print("Accuracy score is:",accuracy_score(y_test,pred))
print("\n")
print("Cross_val_score is:",cross_val_score(svc,x,y,cv=10).mean())
print("\n")
print("Multiclass_roc_auc_score is:",multiclass_roc_auc_score(y_test,pred))
print("\n")
print("Classification_report")
print(classification_report(y_test,pred))
print("\n")
print("Confusion_matirx")
cm=confusion_matrix(y_test,pred)
plt.figure(figsize=(12,8))
sns.heatmap(cm,annot=True)
print(cm)
# Out:
# Accuracy score is: 0.9411764705882353
#
#
# Cross_val_score is: 0.9882352941176471
#
#
# Multiclass_roc_auc_score is: 0.9592074592074592
#
#
# Classification_report
#               precision    recall  f1-score   support
#
#            1       0.86      1.00      0.92        12
#            2       1.00      0.85      0.92        13
#            3       1.00      1.00      1.00         9
#
#     accuracy                           0.94        34
#    macro avg       0.95      0.95      0.95        34
# weighted avg       0.95      0.94      0.94        34
#
#
#
# Confusion_matirx
# [[12  0  0]
#  [ 2 11  0]
#  [ 0  0  9]]

# %% [markdown]
# #### AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier
abc=AdaBoostClassifier()
abc.fit(x_train,y_train)
pred=abc.predict(x_test)
print("Accuracy score is:",accuracy_score(y_test,pred))
print("\n")
print("Cross_val_score is:",cross_val_score(svc,x,y,cv=10).mean())
print("\n")
print("Multiclass_roc_auc_score is:",multiclass_roc_auc_score(y_test,pred))
print("\n")
print("Classification_report")
print(classification_report(y_test,pred))
print("\n")
print("Confusion_matirx")
cm=confusion_matrix(y_test,pred)
plt.figure(figsize=(12,8))
sns.heatmap(cm,annot=True)
print(cm)
# Out:
# Accuracy score is: 0.9117647058823529
#
#
# Cross_val_score is: 0.9882352941176471
#
#
# Multiclass_roc_auc_score is: 0.9345238095238096
#
#
# Classification_report
#               precision    recall  f1-score   support
#
#            1       1.00      0.75      0.86        12
#            2       0.81      1.00      0.90        13
#            3       1.00      1.00      1.00         9
#
#     accuracy                           0.91        34
#    macro avg       0.94      0.92      0.92        34
# weighted avg       0.93      0.91      0.91        34
#
#
#
# Confusion_matirx
# [[ 9  3  0]
#  [ 0 13  0]
#  [ 0  0  9]]

# %% [markdown]
# #### Extra Trees Classifier

# %%
from sklearn.ensemble import ExtraTreesClassifier
etc=ExtraTreesClassifier()
etc.fit(x_train,y_train)
pred=etc.predict(x_test)
print("Accuracy score is:",accuracy_score(y_test,pred))
print("\n")
print("Cross_val_score is:",cross_val_score(svc,x,y,cv=10).mean())
print("\n")
print("Multiclass_roc_auc_score is:",multiclass_roc_auc_score(y_test,pred))
print("\n")
print("Classification_report")
print(classification_report(y_test,pred))
print("\n")
print("Confusion_matirx")
cm=confusion_matrix(y_test,pred)
plt.figure(figsize=(12,8))
sns.heatmap(cm,annot=True)
print(cm)
# Out:
# Accuracy score is: 1.0
#
#
# Cross_val_score is: 0.9882352941176471
#
#
# Multiclass_roc_auc_score is: 1.0
#
#
# Classification_report
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00        13
#            3       1.00      1.00      1.00         9
#
#     accuracy                           1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34
#
#
#
# Confusion_matirx
# [[12  0  0]
#  [ 0 13  0]
#  [ 0  0  9]]

# %% [markdown]
# ### Appending Models

# %%
models = []
models.append(('KNeighborsClassifier',knn))
models.append(('SVC',svc))
models.append(('LogisticRegression',lr))
models.append(('DecisionTreeClassifier',dtc))
models.append(('GaussianNB',gnb))
models.append(('RandomForestClassifier',rfc))
models.append(('GradientBoostingClassifier',gbc))
models.append(('ExtraTreesClassifier',etc))
models.append(('AdaBoostClassifier',abc))

# %% [markdown]
# ### Framing Compare Tables

# %%
Model=[]
ac=[]
cvs=[]
ras=[]
for name, model in models:
    model.fit(x_train, y_train)
    y_pred=model.predict(x_test)
    ac.append(accuracy_score(y_test, y_pred))
    re=cross_val_score(model, x, y, cv=10, scoring='accuracy').mean()
    ras.append(multiclass_roc_auc_score(y_test,y_pred))
    cvs.append(re)
    Model.append(name)
result = pd.DataFrame({'Model': Model, 'Accuracy_score': ac ,'Cross_val_score':cvs,'Roc_auc_score':ras})
result
# Out:
#                         Model  Accuracy_score  Cross_val_score  Roc_auc_score
# 0        KNeighborsClassifier        0.970588         0.952574       0.979604
# 1                         SVC        1.000000         0.988235       1.000000
# 2          LogisticRegression        1.000000         0.988235       1.000000
# 3      DecisionTreeClassifier        0.970588         0.863235       0.979604
# 4                  GaussianNB        1.000000         0.988235       1.000000
# 5      RandomForestClassifier        1.000000         0.982353       1.000000
# 6  GradientBoostingClassifier        0.941176         0.934926       0.959207
# 7        ExtraTreesClassifier        1.000000         0.994118       1.000000
# 8          AdaBoostClassifier        0.911765         0.869853       0.934524

# %%
result.max()   #we will be finalizing this model
# Out:
# Model                   SVC
# Accuracy_score            1
# Cross_val_score    0.994118
# Roc_auc_score             1
# dtype: object

# %% [markdown]
# ### Saving the Model

# %%
import joblib
joblib.dump(svc,"svc_Wine.pkl")
# Out:
# ['svc_Wine.pkl']

# %% [markdown]
# ### Loading Model

# %%
model=joblib.load("svc_Wine.pkl")

# %% [markdown]
# ### Using Model

# %%
model.predict(x_test)
# Out:
# array([2, 3, 2, 3, 2, 2, 1, 3, 1, 2, 2, 1, 3, 3, 1, 1, 3, 1, 3, 1, 2, 1,
#        1, 3, 3, 2, 2, 2, 1, 1, 2, 1, 2, 2], dtype=int64)
