# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
ds_diab=pd.read_csv("diabetes.csv")
ds_diab
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
ds_diab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# ### Checking Null Values

# %%
ds_diab.isnull().sum() #no null values
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
sns.heatmap(ds_diab.isnull())

# %% [markdown]
# ### Describing Statistics

# %%
ds_diab.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
ds_diab.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
corr_hmap=ds_diab.corr()
plt.figure(figsize=(8,7))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %% [markdown]
# ### Bivariate and  Univariate Analysis

# %%
sns.countplot(ds_diab["Outcome"])

# %%
sns.catplot(x='Outcome',y='Pregnancies',kind='bar',data=ds_diab)

# %%
sns.catplot(x='Outcome',y='Glucose',kind='bar',data=ds_diab)

# %%
sns.catplot(x='Outcome',y='BloodPressure',kind='bar',data=ds_diab)

# %%
sns.catplot(x='Outcome',y='SkinThickness',kind='bar',data=ds_diab)

# %%
sns.catplot(x='Outcome',y='Insulin',kind='bar',data=ds_diab)

# %%
sns.catplot(x='Outcome',y='BMI',kind='bar',data=ds_diab)

# %%
sns.catplot(x='Outcome',y='DiabetesPedigreeFunction',kind='bar',data=ds_diab)

# %%
sns.catplot(x='Outcome',y='Age',kind='bar',data=ds_diab)

# %%
sns.pairplot(ds_diab)

# %% [markdown]
# ### Plotting Distribution

# %%
for i in ds_diab.columns:
    plt.figure()
    sns.distplot(ds_diab[i])

# %% [markdown]
# ### Checking Skweness

# %%
ds_diab.skew()
# Out:
# Pregnancies                 0.901674
# Glucose                     0.173754
# BloodPressure              -1.843608
# SkinThickness               0.109372
# Insulin                     2.272251
# BMI                        -0.428982
# DiabetesPedigreeFunction    1.919911
# Age                         1.129597
# Outcome                     0.635017
# dtype: float64

# %% [markdown]
# ### Splliting Training and Testing

# %%
x=ds_diab.iloc[:,0:-1]
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y=ds_diab.iloc[:,-1]
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# ### Plotting Distribution

# %%
for i in ds_diab.columns:
    plt.figure()
    sns.distplot(ds_diab[i])

# %%
ds_diab.skew()
# Out:
# Pregnancies                 0.901674
# Glucose                     0.173754
# BloodPressure              -1.843608
# SkinThickness               0.109372
# Insulin                     2.272251
# BMI                        -0.428982
# DiabetesPedigreeFunction    1.919911
# Age                         1.129597
# Outcome                     0.635017
# dtype: float64

# %% [markdown]
# ### Log Transformatipn

# %%
for col in x:                   
    if x.skew().loc[col]>.55:
        x[col]=np.log1p(x[col])

# %%
for i in x.columns:
    plt.figure()
    sns.distplot(x[i])

# %%
x.skew()
# Out:
# Pregnancies                -0.243478
# Glucose                     0.173754
# BloodPressure              -1.843608
# SkinThickness               0.109372
# Insulin                     0.065978
# BMI                        -0.428982
# DiabetesPedigreeFunction    1.117942
# Age                         0.614664
# dtype: float64

# %% [markdown]
# ### Checking Outliers

# %%
from scipy.stats import zscore
z_score=abs(zscore(x))
print(x.shape)
x_final=x.loc[(z_score<3).all(axis=1)]
print(x_final.shape)
# Out:
# (768, 8)
# (713, 8)

# %%
for i in x.columns:
    plt.figure()
    sns.boxplot(x[i])

# %%
for i in x_final.columns:
    plt.figure()
    sns.boxplot(x_final[i])

# %% [markdown]
# ### Scaling Input Data

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.82578131,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.61205873,  1.43776741],
#        [-0.80260428, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.3249939 , -0.05057458],
#        [ 1.15244868,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.74958593,  0.04768708],
#        ...,
#        [ 0.6254108 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.73687721, -0.15195618],
#        [-0.80260428,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.33246179,  1.24417772],
#        [-0.80260428, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.46113844, -0.96921595]])

# %% [markdown]
# ### Importing Classification Algoritims

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Splitting Training and Testing

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=9,stratify=y)

# %% [markdown]
# ### Putting Aliases

# %%
knn=KNeighborsClassifier(n_neighbors=6)
svc=SVC()
lr=LogisticRegression()
dtc=DecisionTreeClassifier(random_state=8)
gnb=GaussianNB()
rfc=RandomForestClassifier(n_estimators=20,random_state=8)
gbc=GradientBoostingClassifier(random_state=8)
abc=AdaBoostClassifier(random_state=8)
etc=ExtraTreesClassifier(random_state=8)

# %% [markdown]
# ### Appending Models

# %%
models = []
models.append(('KNeighborsClassifier',knn))
models.append(('SVC',svc))
models.append(('LogisticRegression',lr))
models.append(('DecisionTreeClassifier',dtc))
models.append(('GaussianNB',gnb))
models.append(('RandomForestClassifier',rfc))
models.append(('GradientBoostingClassifier',gbc))
models.append(('ExtraTreesClassifier',etc))
models.append(('AdaBoostClassifier',abc))

# %% [markdown]
# ### Importing Metrics

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %% [markdown]
# ### Machine Learning

# %%
Model=[]
score=[]
cvs=[]
rocscore=[]
for name,model in models:
    print("*******************",name,"*********************")
    print("\n")
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pred=model.predict(x_test)
    print("\n")
    AS=accuracy_score(y_test,pred)
    print("Accuracy_score=",AS)
    score.append(AS*100)
    print("\n")
    sc= cross_val_score(model,x,y,cv=10,scoring="accuracy").mean()
    print("Cross_val_score=",sc)
    cvs.append(sc*100)
    print("\n")
    false_positive_rate,true_positive_rate,thresholds=roc_curve(y_test,pred)
    roc_auc=auc(false_positive_rate,true_positive_rate)
    print("roc_auc_score=",roc_auc)
    rocscore.append(roc_auc*100)
    print("\n")
    print("classification_report\n",classification_report(y_test,pred))
    print("\n")
    cm=confusion_matrix(y_test,pred)
    print(cm)
    print("\n")
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot(false_positive_rate,true_positive_rate,label="AUC=%0.2f"% roc_auc)
    plt.plot([0,1],[0,1],"r--")
    plt.legend(loc="lower right")
    plt.ylabel("True Positive Rate")
    plt.xlabel("False Positive Rate")
    print("\n\n")
# Out:
# ******************* KNeighborsClassifier *********************
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=6, p=2,
#                      weights='uniform')
#
#
# Accuracy_score= 0.7619047619047619
#
#
# Cross_val_score= 0.7408749145591251
#
#
# roc_auc_score= 0.6917283950617285
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.76      0.93      0.83       150
#            1       0.77      0.46      0.57        81
#
#     accuracy                           0.76       231
#    macro avg       0.77      0.69      0.70       231
# weighted avg       0.76      0.76      0.74       231
#
#
#
# [[139  11]
#  [ 44  37]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# ******************* SVC *********************
#
#
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
# ...

# %% [markdown]
# ### Comparing Models

# %%
results=pd.DataFrame({"Model":Model,"Accuracy_Score":score,"Cross_Val_Score":cvs,"Roc_Auc_Score":rocscore})
results
# Out:
#                         Model  Accuracy_Score  Cross_Val_Score  Roc_Auc_Score
# 0        KNeighborsClassifier       76.190476        74.087491      69.172840
# 1                         SVC       77.489177        75.394737      72.728395
# 2          LogisticRegression       78.354978        76.565277      73.395062
# 3      DecisionTreeClassifier       72.727273        70.828776      70.481481
# 4                  GaussianNB       77.489177        76.047505      73.296296
# 5      RandomForestClassifier       78.354978        74.608681      73.111111
# 6  GradientBoostingClassifier       77.922078        75.910800      73.913580
# 7        ExtraTreesClassifier       77.922078        76.173958      73.345679
# 8          AdaBoostClassifier       77.489177        75.524607      73.012346

# %% [markdown]
# ### Saving the best Model

# %%
import joblib
joblib.dump(lr,"lr_Diabetes.pkl")
# Out:
# ['lr_Diabetes.pkl']
