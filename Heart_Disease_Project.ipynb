# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Summary

# %% [markdown]
# The below datset have attributes realating to patients and we will be classifying and make a model which will help in predicting if patients have heart disease or not.

# %% [markdown]
# ### Columnal Description

# %% [raw]
# age - age in years
# sex - (1 = male; 0 = female)
# cp - chest pain type
# trestbps - resting blood pressure (in mm Hg on admission to the hospital)
# chol - serum cholestoral in mg/dl
# fbs - (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
# restecg - resting electrocardiographic results
# thalach - maximum heart rate achieved
# exang - exercise induced angina (1 = yes; 0 = no)
# oldpeak - ST depression induced by exercise relative to rest
# slope - the slope of the peak exercise ST segment
# ca - number of major vessels (0-3) colored by flourosopy
# thal - 3 = normal; 6 = fixed defect; 7 = reversable defect
# target - have disease or not (1=yes, 0=no)

# %% [markdown]
# ### Calling DataFrame

# %%
#calling he entire dataset
ds_heart=pd.read_csv("Heart.csv")
ds_heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# ### Describing Information

# %%
#describing information relating to he dataset
ds_heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [raw]
# Observations:
#
# 1) There are 13 numeric columns
#
# 2) There is 1 float column in the dataset.

# %% [markdown]
# ### Plotting Missing Values

# %%
ds_heart.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#plotting Null Values in a Heatmap
sns.heatmap(ds_heart.isnull())

# %% [raw]
# Observations:
#
# No null values in the dataset

# %% [markdown]
# ### Describing Statistics

# %%
#describing statistical description of dataset.
ds_heart.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [raw]
# Observations:
#
# 1) For the columns like chol, exang, old peak and slope where the mean is more than the median, the data must be rightly skewed. We will fix it.
#
# 2) The max for column chol, ca, oldpeak is way more than the 75% of the data so that means there must be outliers present. We will later fix it using z-score.
#
# 3) The maximum age in the datset is 77 and minimum being 29.

# %% [markdown]
# ### Plotting Co-relation

# %%
#plotting co-relation to find reration of one variable to the other.
ds_heart.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
#plotting correlation in a heatmap.
corr_hmap=ds_heart.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %% [raw]
# Observation:
#
# 1) The above data shows co-relation of each variable with the other.
#
# 2) The columns cp, restecg, thalach and slope are  positively co-related to the target variable, while age, sex tresbps, chol, fbs, exang, oldpeak, ca and thal are negatively co-related.

# %%
#plotting a corelation graph
plt.figure(figsize=(8,6))
ds_heart.drop("target",axis=1).corrwith(ds_heart["target"]).plot(kind="bar",grid=True)
plt.xticks(rotation=20)
plt.title("Correlation wih target variable")
# Out:
# Text(0.5, 1.0, 'Correlation wih target variable')

# %% [markdown]
# ### Univariate  Analysis

# %%
#plotting the age distribution of the dataset in the countplot
plt.figure(figsize=(12,4))
sns.countplot(x="age",data=ds_heart)

# %% [raw]
# Observations:
#
# The datset contains people with age group between 29 to 77. The maximum number of people in the dataset is of age 58.

# %%
#plotting types of chest pain and the number of people having them over a countplot. 
plt.figure(figsize=(6,4))
sns.countplot(x="cp",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows the various types of chest pains. Most people have type0 chest pain followed by type2 with type3 being the lowest.

# %%
#plotting the ratio of males to females in the dataset 
plt.figure(figsize=(6,4))
sns.countplot(x="sex",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows the dataset contain more number of males than compared to females.

# %%
#plotting the distribution of blood pressure level in a violin plot
sns.violinplot(x="trestbps",data=ds_heart)

# %% [raw]
# Observations:
#
# Most people have blood pressure randing from 120 to 140.

# %%
#plotting the distribution of cholestrol level in a violin plot
sns.violinplot(x="chol",data=ds_heart)

# %% [raw]
# Observations:
#
# Most people have blood pressure ranging from 200 to 300.

# %%
#plotting the blood sugar level in a countblot.
plt.figure(figsize=(6,4))
sns.countplot(x="fbs",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows fasting blood sugar level > 120 mg/dl where 1 = true and 0 = false. We have more 0 than 1 in the dataset.

# %%
#plotting the electro cardiographic results in a countplot.
plt.figure(figsize=(6,4))
sns.countplot(x="restecg",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows cardiographic results in a countplot. The number of  0 and 1 type results have equal number of patients while result 2 being the lowest.

# %%
#plotting the distribution of heart rate in a violin plot
sns.violinplot(x="thalach",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows most people have heart rate ranging from 140 to 180.

# %%
#plotting exercise induced agina in a countplot
plt.figure(figsize=(6,4))
sns.countplot(x="exang",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows exercise induced agina in a count plot where 1 represents yes and 0 represents no. We can see that we have more 0s than 1s in the dataset.

# %%
#plotting the distribution of result of oldpeak in a violin plot
sns.violinplot(x="oldpeak",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows dataset have more people with result ranging from -0.05 to +0.05

# %%
#plotting the result of peak exercise segment in a countplot.
plt.figure(figsize=(6,4))
sns.countplot(x="slope",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows results of peak exercise column. Type1 and Type2 almost have the same counts with Type0 being the lowest.

# %%
#plotting the results of major vessels in a countplot.
plt.figure(figsize=(6,4))
sns.countplot(x="ca",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows number of major vessels in of the patients with most people having 0 to the least people having 4.

# %%
#plotting the results of defects in a countplot.
plt.figure(figsize=(6,4))
sns.countplot(x="thal",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows number of defects  where 3 = normal, 6 = fixed defect and 7 = reversable defect. The entire datset is under 3 with 2 being the highest.

# %% [markdown]
# ### Bivariate Analysis

# %%
#plotting the target variable according to the age group
plt.figure(figsize=(20,6))
sns.countplot(data=ds_heart,x="age",hue="target")
plt.show()

# %% [raw]
# Observations:
#
# The above diagram shows the age distribution with people either having a heart disease or not.

# %%
#plotting the target variable according to the sex in the dataset
plt.figure(figsize=(6,4))
sns.countplot(data=ds_heart,x="sex",hue="target")
plt.show()

# %% [raw]
# Observations:
#
# The above diagram shows the dataset have more males compared to females with result 1 in the target variable.

# %%
#plotting the target variable according to the chest pain types in the dataset
plt.figure(figsize=(6,4))
sns.countplot(data=ds_heart,x="cp",hue="target")
plt.show()

# %% [raw]
# Observations:
#
# According to the above diagram the most number of people having an heart disease belongs to chest pain type2.

# %%
#plotting the target variable according to sugar level in a count plot
plt.figure(figsize=(5,4))
sns.countplot(data=ds_heart,x="fbs",hue="target")
plt.show()

# %% [raw]
# Observations:
#
# People with lesser sugar level have higher chances of the disease.

# %%
#plotting the age group of people according to the level of blood pressure
plt.figure(figsize=(5,4))
sns.scatterplot(data=ds_heart,x="age",y="trestbps")
plt.show()

# %%
#plotting the age group of people according to the level of cholestrol
plt.figure(figsize=(5,4))
sns.scatterplot(data=ds_heart,x="chol",y="age")
plt.show()

# %%
#plotting the target variable according to exercise
plt.figure(figsize=(5,4))
sns.countplot(data=ds_heart,x="exang",hue="target")
plt.show()

# %% [raw]
# Observations:
#
# The above diagram shows people with no exercise have more chances of the disease.

# %%
#plotting realtionship of all the variables in a pairplot
sns.pairplot(ds_heart)

# %% [markdown]
# ### Plotting Outliers

# %%
#plotting all the variables in a boxplot to find 
for i in ds_heart.columns:
    plt.figure()
    sns.boxplot(ds_heart[i])

# %%
#plotting outliers for all the variables in a single view format for a better understanding
collist=ds_heart.columns.values
ncol=17
nrow=10
plt.figure(figsize=(30,50))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(ds_heart[collist[i]],color="green",orient="v")
    plt.tight_layout()

# %% [markdown]
# ### Plotting Distribution

# %%
#plotting distribution of the variabels in the dataset
sns.distplot(ds_heart["trestbps"])

# %%
sns.distplot(ds_heart["chol"])

# %%
sns.distplot(ds_heart["thalach"])

# %%
sns.distplot(ds_heart["oldpeak"])

# %% [markdown]
# ### Checking Skewness

# %%
ds_heart.skew()
# Out:
# age        -0.202463
# sex        -0.791335
# cp          0.484732
# trestbps    0.713768
# chol        1.143401
# fbs         1.986652
# restecg     0.162522
# thalach    -0.537410
# exang       0.742532
# oldpeak     1.269720
# slope      -0.508316
# ca          1.310422
# thal       -0.476722
# target     -0.179821
# dtype: float64

# %% [markdown]
# ### Fixing Outliers

# %%
#using Zscore to remove the outliers
from scipy.stats import zscore
z=np.abs(zscore(ds_heart))
threshold=3
print(np.where(z>3))
ds_heart_new=ds_heart[(z<3).all(axis=1)]
print(ds_heart.shape)
print(ds_heart_new.shape)
# Out:
# (array([ 28,  48,  85,  92, 158, 163, 164, 204, 220, 221, 223, 246, 248,
#        251, 272, 281], dtype=int64), array([ 4, 12,  4, 11, 11, 11, 11,  9,  4,  9,  3,  4,  3, 11,  7, 12],
#       dtype=int64))
# (303, 14)
# (287, 14)

# %% [markdown]
# ### Log Transformation

# %%
#using log transformation technique to reduce data skewness
for i in ds_heart_new.columns:
    if ds_heart_new[i].skew()>.55:
        ds_heart_new[i]=np.log1p(ds_heart_new[i])

# %% [markdown]
# ### Rechecking Skewness

# %%
ds_heart_new.skew()
# Out:
# age        -0.184321
# sex        -0.825426
# cp          0.491220
# trestbps    0.530712
# chol        0.245591
# fbs         2.051982
# restecg     0.155787
# thalach    -0.473864
# exang       0.738876
# oldpeak     0.331394
# slope      -0.503916
# ca          0.765030
# thal       -0.190864
# target     -0.204199
# dtype: float64

# %% [markdown]
# ### Seperating Target and Input variables

# %%
#splitting the data into target and input variable for the classification study  
ds_heart_x=ds_heart_new.drop(columns="target")
y=pd.DataFrame(ds_heart_new["target"])

# %%
#calling input variables
ds_heart_x
# Out:
#      age  sex  cp  trestbps  chol       fbs  restecg  thalach     exang  \
# 0     63    1   3       145   233  0.693147        0      150  0.000000
# 1     37    1   2       130   250  0.000000        1      187  0.000000
# 2     41    0   1       130   204  0.000000        0      172  0.000000
# 3     56    1   1       120   236  0.000000        1      178  0.000000
# 4     57    0   0       120   354  0.000000        1      163  0.693147
# ..   ...  ...  ..       ...   ...       ...      ...      ...       ...
# 298   57    0   0       140   241  0.000000        1      123  0.693147
# 299   45    1   3       110   264  0.000000        1      132  0.000000
# 300   68    1   0       144   193  0.693147        1      141  0.000000
# 301   57    1   0       130   131  0.000000        1      115  0.693147
# 302   57    0   1       130   236  0.000000        0      174  0.000000
#
#       oldpeak  slope        ca  thal
# 0    1.193922      0  0.000000     1
# ...

# %%
#calling arget variable
y
# Out:
#      target
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 298       0
# 299       0
# 300       0
# 301       0
# 302       0
#
# [287 rows x 1 columns]

# %% [markdown]
# ### Scaling the Input Variables

# %%
#using standard scaler to scale input variables
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(ds_heart_x)
x=pd.DataFrame(x,columns=ds_heart_x.columns)
x
# Out:
#           age       sex        cp  trestbps      chol       fbs   restecg  \
# 0    0.954638  0.670444  1.958231  0.823925 -0.250907  2.449490 -1.013312
# 1   -1.909660  0.670444  0.992574 -0.060392  0.119943 -0.408248  0.887476
# 2   -1.468998 -1.491549  0.026917 -0.060392 -0.883533 -0.408248 -1.013312
# 3    0.183481  0.670444  0.026917 -0.649938 -0.185463 -0.408248  0.887476
# 4    0.293646 -1.491549 -0.938740 -0.649938  2.388672 -0.408248  0.887476
# ..        ...       ...       ...       ...       ...       ...       ...
# 282  0.293646 -1.491549 -0.938740  0.529153 -0.076389 -0.408248  0.887476
# 283 -1.028337  0.670444  1.958231 -1.239483  0.425349 -0.408248  0.887476
# 284  1.505464  0.670444 -0.938740  0.764971 -1.123495  2.449490  0.887476
# 285  0.293646  0.670444 -0.938740 -0.060392 -2.476007 -0.408248  0.887476
# 286  0.293646 -1.491549  0.026917 -0.060392 -0.185463 -0.408248 -1.013312
#
#       thalach     exang   oldpeak     slope        ca      thal
# ...

# %% [markdown]
# ### Seperating Training and Testing data

# %%
#using train_test_split to seperate training and testing data
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (229, 13)
# (58, 13)
# (229, 1)
# (58, 1)

# %% [markdown]
# ### Importing Classification Algorithims and Metrices

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %% [markdown]
# ### Putting Aliases

# %%
knn=KNeighborsClassifier()
svc=SVC()
lr=LogisticRegression()
dtc=DecisionTreeClassifier()
gnb=GaussianNB()
rfc=RandomForestClassifier()
gbc=GradientBoostingClassifier()
abc=AdaBoostClassifier()
etc=ExtraTreesClassifier()

# %% [markdown]
# ### Appending Models

# %%
models = []
models.append(('KNeighborsClassifier',knn))
models.append(('SVC',svc))
models.append(('LogisticRegression',lr))
models.append(('DecisionTreeClassifier',dtc))
models.append(('GaussianNB',gnb))
models.append(('RandomForestClassifier',rfc))
models.append(('GradientBoostingClassifier',gbc))
models.append(('ExtraTreesClassifier',etc))
models.append(('AdaBoostClassifier',abc))

# %% [markdown]
# ### Machine Learning

# %%
Model=[]
score=[]
cvs=[]
rocscore=[]
for name,model in models:
    print("*******************",name,"*********************")
    print("\n")
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pred=model.predict(x_test)
    print("\n")
    AS=accuracy_score(y_test,pred)
    print("Accuracy_score=",AS)
    score.append(AS*100)
    print("\n")
    sc= cross_val_score(model,x,y,cv=10,scoring="accuracy").mean()
    print("Cross_val_score=",sc)
    cvs.append(sc*100)
    print("\n")
    false_positive_rate,true_positive_rate,thresholds=roc_curve(y_test,pred)
    roc_auc=auc(false_positive_rate,true_positive_rate)
    print("roc_auc_score=",roc_auc)
    rocscore.append(roc_auc*100)
    print("\n")
    print("classification_report\n",classification_report(y_test,pred))
    print("\n")
    cm=confusion_matrix(y_test,pred)
    print(cm)
    print("\n")
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot(false_positive_rate,true_positive_rate,label="AUC=%0.2f"% roc_auc)
    plt.plot([0,1],[0,1],"r--")
    plt.legend(loc="lower right")
    plt.ylabel("True Positive Rate")
    plt.xlabel("False Positive Rate")
    print("\n\n")
# Out:
# ******************* KNeighborsClassifier *********************
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')
#
#
# Accuracy_score= 0.8103448275862069
#
#
# Cross_val_score= 0.8151477832512315
#
#
# roc_auc_score= 0.8055900621118013
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.75      0.78      0.77        23
#            1       0.85      0.83      0.84        35
#
#     accuracy                           0.81        58
#    macro avg       0.80      0.81      0.80        58
# weighted avg       0.81      0.81      0.81        58
#
#
#
# [[18  5]
#  [ 6 29]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# ******************* SVC *********************
#
#
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
# ...

# %% [markdown]
# ### Comparing Models

# %%
results=pd.DataFrame({"Model":Model,"Accuracy_Score":score,"Cross_Val_Score":cvs,"Roc_Auc_Score":rocscore})
results
# Out:
#                         Model  Accuracy_Score  Cross_Val_Score  Roc_Auc_Score
# 0        KNeighborsClassifier       81.034483        81.514778      80.559006
# 1                         SVC       77.586207        84.655172      77.701863
# 2          LogisticRegression       86.206897        83.953202      84.844720
# 3      DecisionTreeClassifier       77.586207        74.581281      78.447205
# 4                  GaussianNB       81.034483        82.573892      82.049689
# 5      RandomForestClassifier       75.862069        83.633005      77.018634
# 6  GradientBoostingClassifier       75.862069        80.800493      75.527950
# 7        ExtraTreesClassifier       75.862069        81.871921      75.527950
# 8          AdaBoostClassifier       77.586207        81.847291      77.701863

# %% [raw]
# Observation:
#
# We will be finalizing Logistic Regression for this dataset as it gives the best result according to the above table.

# %% [markdown]
# ### Saving Model

# %%
import joblib
joblib.dump(lr,"Model_Heart_Disease_lr.csv")
# Out:
# ['Model_Heart_Disease_lr.csv']

# %% [markdown]
# ### Loading Model

# %%
Model_Heart_Disease=joblib.load("Model_Heart_Disease_lr.csv")

# %% [markdown]
# ### Using Model

# %%
pd.DataFrame(Model_Heart_Disease.predict(x_test))
# Out:
#     0
# 0   1
# 1   0
# 2   1
# 3   0
# 4   1
# 5   0
# 6   0
# 7   1
# 8   1
# 9   0
# 10  1
# 11  0
# 12  1
# 13  1
# 14  1
# 15  0
# 16  0
# 17  0
# 18  1
# 19  0
# 20  0
# 21  1
# 22  1
# 23  1
# 24  1
# 25  1
# 26  1
# 27  1
# 28  1
# 29  1
# 30  1
# 31  1
# 32  0
# 33  1
# 34  1
# 35  1
# 36  1
# 37  1
# 38  1
# 39  1
# 40  1
# 41  1
# 42  1
# 43  1
# 44  0
# 45  0
# 46  1
# 47  0
# 48  0
# 49  0
# 50  0
# 51  0
# 52  0
# 53  1
# 54  1
# 55  1
# 56  0
# 57  1
