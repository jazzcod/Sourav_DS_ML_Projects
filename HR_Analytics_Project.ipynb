# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Summary

# %% [markdown]
# Every yearcompanies hire employees. The companies invest time and money in training the new employees and the existing employees. The purpose of these programs is to increase the effectiveness and efficiency of their employees. HR Analytics is not just about improving the performance of employees but also applying analytics for improving employee performance and productivity for a better ROI. HR analytics by with gathering data aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes. Attrition in human resources refers to the gradual loss of employees over time. In general, relatively high attrition is problematic for companies. HR professionals often assume a leadership role in designing company compensation programs, work culture and motivation systems that help the organization retain top employees.HR Analytics helps to undestand how Attrition affect companies? and how does HR Analytics can reduce attrition. A major problem in high employee attrition is its cost to an organization.

# %% [markdown]
# ###  Calling DataFrame

# %%
#calling the entire dataframe
ds_hr=pd.read_csv("hrdata.csv")
ds_hr
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ### Describing Information

# %%
#describing information related to the dataset
ds_hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [raw]
# Observations:
#
# 1) There are total 26 numeric columns and 9 categorical columns.
#
# 2) No null values in the dataset.

# %% [markdown]
# ### Checking Null Values

# %%
#cheking Null Values in the dataset
ds_hr.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#plotting Null Values in a Heatmap
sns.heatmap(ds_hr.isnull())

# %% [raw]
# Observations:
#
# 1) No Null Values in the Dataset.

# %% [markdown]
# ### Encoding Target Variable

# %%
#using label encoder to encode the target variable 
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
ds_hr["Attrition"]=le.fit_transform(ds_hr["Attrition"].astype(str))
ds_hr
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ### Describing Statistics

# %%
#describing statistical information related to te dataset
ds_hr.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.161224   802.485714          9.192517     2.912925
# std       9.135373     0.367863   403.509100          8.106864     1.024165
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.000000          2.000000     2.000000
# 50%      36.000000     0.000000   802.000000          7.000000     3.000000
# 75%      43.000000     0.000000  1157.000000         14.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769    65.891156
# ...

# %% [raw]
# Observations:
#
# 1) The difference of maximum value to that of 75% in columns DailyRate, Distance from Home, Total working hours, Years Since Last Promotion, Years in current Role and Years with current manager is more, so outliers are present in these columns.
#
# 2)For the columns Distance FRom Home, Years since last promotion, Years in current role, the mean is greater than the median, so this means the data is rightly skewed. We will fix them later using z-score.
#
# 3)Fro the columns where the mean is a bit leser than median, the data is left skewed.

# %% [markdown]
# ### Plotting Co-relation

# %%
#describing the co-relation co-effcient of data 
ds_hr.corr()
# Out:
#                                Age  Attrition  DailyRate  DistanceFromHome  \
# Age                       1.000000  -0.159205   0.010661         -0.001686
# Attrition                -0.159205   1.000000  -0.056652          0.077924
# DailyRate                 0.010661  -0.056652   1.000000         -0.004985
# DistanceFromHome         -0.001686   0.077924  -0.004985          1.000000
# Education                 0.208034  -0.031373  -0.016806          0.021042
# EmployeeCount                  NaN        NaN        NaN               NaN
# EmployeeNumber           -0.010145  -0.010577  -0.050990          0.032916
# EnvironmentSatisfaction   0.010146  -0.103369   0.018355         -0.016075
# HourlyRate                0.024287  -0.006846   0.023381          0.031131
# JobInvolvement            0.029820  -0.130016   0.046135          0.008783
# JobLevel                  0.509604  -0.169105   0.002966          0.005303
# ...

# %%
#plotting co-relation in a heatmap
corr_hmap=ds_hr.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %% [raw]
# Observations:
#
# 1) From the above heatmap it is understandable that variables that has years (Years at company, years at current role, years since last promoion etc) are positively co-related to each other with a greater co-efficient.
#
# 2) With the target variable (Attrition), variables such as Distance from home, Number of Companies Worked, environmental satisfaction, performance rating are positively correlated with a higher co-efficient.
#
# 3) The Employee Count and the Standard hours came as blank because they have same data in all the rows. Anyways we will be dropping them later while considering the final model.

# %% [markdown]
# ### Univariate Analysis

# %%
#plotting the average age of the people in the dataset
sns.set(style="whitegrid")
sns.violinplot(ds_hr["Age"])
plt.show()

# %% [raw]
# Observations:
#
# The majority of the people in the Dataset belongs to the age group of 30 to 40

# %%
#plotting the distribution of Daily Rate over a violin plot
sns.set(style="whitegrid")
sns.violinplot(ds_hr["DailyRate"])
plt.show()

# %% [raw]
# Observations:
#
# The majority people in the Dataset belongs to the Daily Rate which is between of 250 to 1250

# %%
#plotting number of people in the datset based on their occurence of travel
sns.countplot(x="BusinessTravel",data=ds_hr)

# %% [raw]
# Observaions:
#
# Most of the people in the dataset are the ones travelling rarely with non-travellers the least

# %%
#plotting the numbers of people in the dataset based on the departments they were working in.  
sns.countplot(x="Department",data=ds_hr)

# %% [raw]
# Observations:
#
# The above barplot shows the number of people in the dataset who belongs to the above three departments.

# %%
#plotting the number of employess according to their educational background
plt.figure(figsize=(10,4))
sns.countplot(x="EducationField",data=ds_hr)
plt.show()

# %% [raw]
# Observations:
#
# The above bar plot shows the majoriy of the people are from Life Sciences and Medical backgrounds followed by Marketing.

# %%
#plotting the number of employess according to their maritial status
plt.figure(figsize=(5,4))
sns.countplot(x="MaritalStatus",data=ds_hr)
plt.show()

# %% [raw]
# Observations:
#
# The marital status of most employees in the dataset are married.

# %%
##plotting the number of employees according to their gender
plt.figure(figsize=(5,4))
sns.countplot(x="Gender",data=ds_hr)
plt.show()

# %% [raw]
# Observations:
#
# From the above diagram its inferred that most employees are males in the dataset.

# %%
#plotting the age distribution of the employees in the dataset 
plt.figure(figsize=(8,4))
plt.hist(ds_hr["Age"],bins=10)
plt.show()

# %% [raw]
# Observations:
#
# From the above diagram it can be infered that most of the employees belongs to the age group of 30 to 40

# %% [markdown]
# ### Bivariate Analysis

# %%
#plotting the distribution of age in the dataset in terms of attrition
plt.figure(figsize=(20,6))
sns.countplot(data=ds_hr,x="Age",hue="Attrition")
plt.show()

# %% [raw]
# Observations:
#
# The above diagram shows the number of employees and their ages and whether there was attrition or not. 0 represents (no attrition) whereas 1 represents (yes attrition).

# %%
#plotting attrition and rentention fom different departments
plt.figure(figsize=(7,5))
sns.countplot(data=ds_hr,x="Department",hue="Attrition")
plt.show()

# %% [raw]
# Observations:
#
# The above diagram shows the attrition and retention of employees in different departments and it shows the most attrition is from the R&D department followed by Sales

# %%
#plotting attrition and rentention based on educational field
plt.figure(figsize=(10,5))
sns.countplot(data=ds_hr,x="EducationField",hue="Attrition")
plt.show()

# %% [raw]
# Observations:
#
# The above diagram shows that the most attrition was from the people belonging to the life sciences background followed by medical.

# %%
#plotting attrition and rentention based on frequency of travel
plt.figure(figsize=(7,4))
sns.countplot(data=ds_hr,x="BusinessTravel",hue="Attrition")
plt.show()

# %% [raw]
# Observations:
#
# According to the above diagram the most attrition was from the people who used to rarely travel.

# %%
#plotting attrition and rentention based on gender
plt.figure(figsize=(5,4))
sns.countplot(data=ds_hr,x="Gender",hue="Attrition")
plt.show()

# %% [raw]
# Observations:
#
# Male attrition rate was higher than females.

# %%
#plotting attrition and rentention based on gender
plt.figure(figsize=(5,4))
sns.countplot(data=ds_hr,x="MaritalStatus",hue="Attrition")
plt.show()

# %% [raw]
# Observations:
#
# Attrition rate was higher in people who were single.

# %%
#plotting attrition and rentention based on salary hikes
plt.figure(figsize=(5,4))
sns.countplot(data=ds_hr,x="PercentSalaryHike",hue="Attrition")
plt.show()

# %% [raw]
# Observations:
#
# The above diagram shows people with lesser percentage hikes have more attrition rate

# %%
#plotting attrition and rentention based on performance ratings
plt.figure(figsize=(5,4))
sns.countplot(data=ds_hr,x="PerformanceRating",hue="Attrition")
plt.show()

# %% [raw]
# Observations:
#
# The above diagram shows employees with low perfomance rating have greater attrition rate.

# %%
#plotting attrition and rentention based on relationship satisfaction
plt.figure(figsize=(5,4))
sns.countplot(data=ds_hr,x="RelationshipSatisfaction",hue="Attrition")
plt.show()

# %% [raw]
# Observations:
#
# Employees with relationship satisfaction 3 have the maximum attrition rate

# %%
#plotting attrition and rentention based on employee stock option level 
plt.figure(figsize=(5,4))
sns.countplot(data=ds_hr,x="StockOptionLevel",hue="Attrition")
plt.show()

# %% [raw]
# Observations:
#
# Employees with stock option 0 have the maximum attrition rate

# %%
#plotting attrition and rentention based on total working years
plt.figure(figsize=(20,4))
sns.countplot(data=ds_hr,x="TotalWorkingYears",hue="Attrition")
plt.show()

# %% [raw]
# Observations:
#
# The above diagram shows employees with one year of experience have he highest attrition rate

# %%
#plotting attrition and rentention based on their stint at company 
plt.figure(figsize=(20,4))
sns.countplot(data=ds_hr,x="YearsAtCompany",hue="Attrition")
plt.show()

# %% [raw]
# Observations:
#
# The above diagram shows attrition is highest with people who was there in company for just an year

# %%
#plotting attrition and rentention based on their years since last promotion 
plt.figure(figsize=(20,4))
sns.countplot(data=ds_hr,x="YearsSinceLastPromotion",hue="Attrition")
plt.show()

# %% [markdown]
# the above diagram shows attrition is highest with people who was were never promoted.

# %% [markdown]
# ### Encoding and Quantifying

# %%
#using label encoder to encode the categorival variables
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
ds_hr["BusinessTravel"]=le.fit_transform(ds_hr["BusinessTravel"].astype(str))
ds_hr["Department"]=le.fit_transform(ds_hr["Department"].astype(str))
ds_hr["EducationField"]=le.fit_transform(ds_hr["EducationField"].astype(str))
ds_hr["Gender"]=le.fit_transform(ds_hr["Gender"].astype(str))
ds_hr["JobRole"]=le.fit_transform(ds_hr["JobRole"].astype(str))
ds_hr["MaritalStatus"]=le.fit_transform(ds_hr["MaritalStatus"].astype(str))
ds_hr["Over18"]=le.fit_transform(ds_hr["Over18"].astype(str))
ds_hr["OverTime"]=le.fit_transform(ds_hr["OverTime"].astype(str))
ds_hr
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %% [markdown]
# ### Plotting Outliers

# %%
#plotting all the variables in a boxplot to find 
for i in ds_hr.columns:
    plt.figure()
    sns.boxplot(ds_hr[i])

# %%
#plotting outliers for all the variables in a single view format for a better understanding
collist=ds_hr.columns.values
ncol=17
nrow=10
plt.figure(figsize=(30,50))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(ds_hr[collist[i]],color="green",orient="v")
    plt.tight_layout()

# %% [markdown]
# ### Plotting Distribution

# %%
#plotting distribution of the all variabels in the dataset
sns.distplot(ds_hr["Age"])

# %%
sns.distplot(ds_hr["BusinessTravel"])

# %%
sns.distplot(ds_hr["DailyRate"])

# %%
sns.distplot(ds_hr["DailyRate"])

# %%
sns.distplot(ds_hr["DistanceFromHome"])

# %%
sns.distplot(ds_hr["Education"])

# %%
sns.distplot(ds_hr["EnvironmentSatisfaction"])

# %%
sns.distplot(ds_hr["HourlyRate"])

# %%
sns.distplot(ds_hr["JobInvolvement"])

# %%
sns.distplot(ds_hr["JobInvolvement"])

# %%
sns.distplot(ds_hr["JobLevel"])

# %%
sns.distplot(ds_hr["JobRole"])

# %%
sns.distplot(ds_hr["JobSatisfaction"])

# %%
sns.distplot(ds_hr["MaritalStatus"])

# %%
sns.distplot(ds_hr["MonthlyIncome"])

# %%
sns.distplot(ds_hr["MonthlyRate"])

# %%
sns.distplot(ds_hr["PercentSalaryHike"])

# %%
sns.distplot(ds_hr["RelationshipSatisfaction"])

# %%
sns.distplot(ds_hr["StockOptionLevel"])

# %%
sns.distplot(ds_hr["TotalWorkingYears"])

# %%
sns.distplot(ds_hr["TrainingTimesLastYear"])

# %%
sns.distplot(ds_hr["WorkLifeBalance"])

# %%
sns.distplot(ds_hr["YearsAtCompany"])

# %%
sns.distplot(ds_hr["YearsInCurrentRole"])

# %%
sns.distplot(ds_hr["YearsSinceLastPromotion"])

# %%
sns.distplot(ds_hr["YearsWithCurrManager"])

# %% [markdown]
# ### Checking Skewness

# %%
ds_hr.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome            0.958118
# Education                  -0.289681
# EducationField              0.550371
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# Over18                      0.000000
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# ...

# %% [markdown]
# ### Dropping Columns

# %%
#we will be dropping the lesser important columns as we will not consider them in the final Model.
ds_hr.drop("EmployeeCount",inplace=True,axis=1)
ds_hr.drop("EmployeeNumber",inplace=True,axis=1)
ds_hr.drop("StandardHours",inplace=True,axis=1)
ds_hr.drop("Over18",inplace=True,axis=1)

# %%
ds_hr
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %% [markdown]
# ### Removing Outliers

# %%
#using Zscore to remove the outliers
from scipy.stats import zscore
z=np.abs(zscore(ds_hr))
threshold=3
print(np.where(z>3))
ds_hr_new=ds_hr[(z<3).all(axis=1)]
print(ds_hr.shape)
print(ds_hr_new.shape)
# Out:
# (array([  28,   45,   62,   62,   63,   64,   85,   98,   98,  110,  123,
#         123,  123,  126,  126,  126,  153,  178,  187,  187,  190,  190,
#         218,  231,  231,  237,  237,  270,  270,  281,  326,  386,  386,
#         401,  411,  425,  425,  427,  445,  466,  473,  477,  535,  561,
#         561,  584,  592,  595,  595,  595,  616,  624,  635,  653,  653,
#         677,  686,  701,  716,  746,  749,  752,  799,  838,  861,  861,
#         875,  875,  894,  914,  914,  918,  922,  926,  926,  937,  956,
#         962,  976,  976, 1008, 1024, 1043, 1078, 1078, 1086, 1086, 1093,
#        1111, 1116, 1116, 1135, 1138, 1138, 1156, 1184, 1221, 1223, 1242,
#        1295, 1301, 1301, 1303, 1327, 1331, 1348, 1351, 1401, 1414, 1430],
#       dtype=int64), array([30, 29, 27, 29, 28, 29, 24, 24, 27, 29, 28, 29, 30, 24, 27, 29, 30,
#        29, 24, 30, 27, 28, 29, 28, 30, 27, 29, 24, 27, 28, 29, 29, 30, 24,
# ...

# %% [markdown]
# ### Seperating Target and Input Variables

# %%
#splitting the data into target and input variable for the regression study  
ds_hr_x=ds_hr_new.drop(columns="Attrition")
y=pd.DataFrame(ds_hr_new["Attrition"])

# %%
#calling Input Variables
ds_hr_x
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               2       1102           2                 1          2
# 1      49               1        279           1                 8          1
# 2      37               2       1373           1                 2          2
# 3      33               1       1392           1                 3          4
# 4      27               2        591           1                 2          1
# ...   ...             ...        ...         ...               ...        ...
# 1465   36               1        884           1                23          2
# 1466   39               2        613           1                 6          1
# 1467   27               2        155           1                 4          3
# 1468   49               1       1023           2                 2          3
# 1469   34               2        628           1                 8          3
#
# ...

# %%
#calling target variable
y
# Out:
#       Attrition
# 0             1
# 1             0
# 2             1
# 3             0
# 4             0
# ...         ...
# 1465          0
# 1466          0
# 1467          0
# 1468          0
# 1469          0
#
# [1387 rows x 1 columns]

# %% [markdown]
# ### Log Transformation

# %%
#using log transformation technique to reduce data skewness
for i in ds_hr_x.columns:
    if ds_hr_x[i].skew()>.55:
        ds_hr_x[i]=np.log1p(ds_hr_x[i])

# %% [markdown]
# ### Re-checking Skewness

# %%
ds_hr_x.skew()
# Out:
# Age                         0.472280
# BusinessTravel             -1.426774
# DailyRate                  -0.017078
# Department                  0.183919
# DistanceFromHome           -0.031570
# Education                  -0.289024
# EducationField              0.544868
# EnvironmentSatisfaction    -0.325285
# Gender                     -0.417296
# HourlyRate                 -0.030481
# JobInvolvement             -0.501401
# JobLevel                    0.497167
# JobRole                    -0.386843
# JobSatisfaction            -0.345612
# MaritalStatus              -0.160952
# MonthlyIncome               0.318873
# MonthlyRate                 0.030596
# NumCompaniesWorked          0.101288
# OverTime                    0.954751
# PercentSalaryHike           0.496106
# PerformanceRating           1.931566
# RelationshipSatisfaction   -0.295686
# StockOptionLevel            0.275912
# TotalWorkingYears          -0.728348
# TrainingTimesLastYear      -1.044321
# ...

# %% [markdown]
# ### Replotting Outliers

# %%
#plotting all the variables in a boxplot to find 
for i in ds_hr_x.columns:
    plt.figure()
    sns.boxplot(ds_hr_x[i])

# %%
#plotting outliers for all the variables in a single view format for a better understanding
collist=ds_hr_x.columns.values
ncol=17
nrow=10
plt.figure(figsize=(30,50))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(ds_hr_x[collist[i]],color="green",orient="v")
    plt.tight_layout()

# %% [markdown]
# ### Scaling the Input Variables

# %%
#using standard scaler to scale input variables
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(ds_hr_x)
x=pd.DataFrame(x,columns=ds_hr_x.columns)
x
# Out:
#            Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0     0.536681        0.593126   0.734325    1.405373         -1.502086
# 1     1.442111       -0.905354  -1.307769   -0.496337          0.253886
# 2     0.083966        0.593126   1.406752   -0.496337         -1.028716
# 3    -0.368749       -0.905354   1.453896   -0.496337         -0.692855
# 4    -1.047821        0.593126  -0.533609   -0.496337         -1.028716
# ...        ...             ...        ...         ...               ...
# 1382 -0.029213       -0.905354   0.193406   -0.496337          1.398978
# 1383  0.310324        0.593126  -0.479021   -0.496337         -0.039518
# 1384 -1.047821        0.593126  -1.615447   -0.496337         -0.432340
# 1385  1.442111       -0.905354   0.538304    1.405373         -1.028716
# 1386 -0.255570        0.593126  -0.441802   -0.496337          0.253886
#
#       Education  EducationField  EnvironmentSatisfaction    Gender  \
# ...

# %% [markdown]
# ### Principal Component Analysis

# %%
#using PCA to lesser down the columns
from sklearn.decomposition import PCA
pca=PCA(10)
x=pca.fit_transform(x)
x=pd.DataFrame(x)
x
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.453250  0.546634 -2.420284  0.020029 -0.085131 -3.428064 -0.340072
# 1    -1.333660 -0.769364  1.529353  2.611585 -0.321645  0.758604  0.392406
# 2     3.568891  1.865348 -0.316230  0.043747  1.490244  0.277182  1.758191
# 3     0.459120 -0.897710 -0.833508 -0.974934  0.509016 -1.128893  1.371886
# 4     1.414424  0.179514  0.541468 -1.307176  1.043435  1.208592  0.040570
# ...        ...       ...       ...       ...       ...       ...       ...
# 1382  0.106325  0.529651  1.236864 -0.266879  0.407120 -0.563407  0.500556
# 1383 -1.805400  0.229777  0.762444 -0.456862  0.990308  2.944555  1.545802
# 1384  0.511279 -0.009654  1.845853  1.957648 -0.409454 -2.255222 -1.524745
# 1385 -1.573336 -0.210289 -1.311974 -0.004496 -0.269309  0.142118  0.668331
# 1386  0.357796 -0.021384 -0.048377 -0.883209  1.069997  0.795134 -1.467706
#
#              7         8         9
# ...

# %% [markdown]
# ### Seperating Training and Testing Data

# %%
#using train_test_split to seperate training and testing data
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1109, 10)
# (278, 10)
# (1109, 1)
# (278, 1)

# %% [markdown]
# ### Importing Classification Algorithims and Metrices

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %% [markdown]
# ### Putting Aliases

# %%
knn=KNeighborsClassifier()
svc=SVC()
lr=LogisticRegression()
dtc=DecisionTreeClassifier()
gnb=GaussianNB()
rfc=RandomForestClassifier()
gbc=GradientBoostingClassifier()
abc=AdaBoostClassifier()
etc=ExtraTreesClassifier()

# %% [markdown]
# ### Appending Models

# %%
models = []
models.append(('KNeighborsClassifier',knn))
models.append(('SVC',svc))
models.append(('LogisticRegression',lr))
models.append(('DecisionTreeClassifier',dtc))
models.append(('GaussianNB',gnb))
models.append(('RandomForestClassifier',rfc))
models.append(('GradientBoostingClassifier',gbc))
models.append(('ExtraTreesClassifier',etc))
models.append(('AdaBoostClassifier',abc))

# %% [markdown]
# ### Machine Learning

# %%
Model=[]
score=[]
cvs=[]
rocscore=[]
for name,model in models:
    print("*******************",name,"*********************")
    print("\n")
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pred=model.predict(x_test)
    print("\n")
    AS=accuracy_score(y_test,pred)
    print("Accuracy_score=",AS)
    score.append(AS*100)
    print("\n")
    sc= cross_val_score(model,x,y,cv=10,scoring="accuracy").mean()
    print("Cross_val_score=",sc)
    cvs.append(sc*100)
    print("\n")
    false_positive_rate,true_positive_rate,thresholds=roc_curve(y_test,pred)
    roc_auc=auc(false_positive_rate,true_positive_rate)
    print("roc_auc_score=",roc_auc)
    rocscore.append(roc_auc*100)
    print("\n")
    print("classification_report\n",classification_report(y_test,pred))
    print("\n")
    cm=confusion_matrix(y_test,pred)
    print(cm)
    print("\n")
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot(false_positive_rate,true_positive_rate,label="AUC=%0.2f"% roc_auc)
    plt.plot([0,1],[0,1],"r--")
    plt.legend(loc="lower right")
    plt.ylabel("True Positive Rate")
    plt.xlabel("False Positive Rate")
    print("\n\n")
# Out:
# ******************* KNeighborsClassifier *********************
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')
#
#
# Accuracy_score= 0.8273381294964028
#
#
# Cross_val_score= 0.8356062975706392
#
#
# roc_auc_score= 0.5606705241660993
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.83      0.99      0.90       226
#            1       0.70      0.13      0.23        52
#
#     accuracy                           0.83       278
#    macro avg       0.77      0.56      0.56       278
# weighted avg       0.81      0.83      0.78       278
#
#
#
# [[223   3]
#  [ 45   7]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# ******************* SVC *********************
#
#
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
# ...

# %% [markdown]
# ### Comparing Models

# %%
results=pd.DataFrame({"Model":Model,"Accuracy_Score":score,"Cross_Val_Score":cvs,"Roc_Auc_Score":rocscore})
results
# Out:
#                         Model  Accuracy_Score  Cross_Val_Score  Roc_Auc_Score
# 0        KNeighborsClassifier       82.733813        83.560630      56.067052
# 1                         SVC       81.654676        83.780106      51.701838
# 2          LogisticRegression       83.453237        84.643937      58.730429
# 3      DecisionTreeClassifier       79.496403        77.002398      63.699796
# 4                  GaussianNB       83.453237        85.077156      58.730429
# 5      RandomForestClassifier       84.532374        85.364404      59.394146
# 6  GradientBoostingClassifier       84.172662        85.006777      60.653506
# 7        ExtraTreesClassifier       82.733813        85.077156      54.586453
# 8          AdaBoostClassifier       84.532374        84.575644      62.355344

# %% [markdown]
# We will be considering Random Forest for this Dataset as it gives the maximum score.

# %% [markdown]
# ### HyperParameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
parameterrfc={"n_estimators":[20,30,40,50,60,70,80,90,100],
             "criterion":["gini","entropy"],
             "max_features":["auto","sqrt","log2"],
             "max_depth":[2,3,4,5,6,None]}
gridrfc=GridSearchCV(rfc,param_grid=parameterrfc,n_jobs=-1,cv=10)
gridrfc.fit(x_train,y_train)
gridrfc.best_score_,gridrfc.best_params_
# Out:
# (0.8584438984438985,
#  {'criterion': 'entropy',
#   'max_depth': None,
#   'max_features': 'auto',
#   'n_estimators': 40})

# %% [markdown]
# ### Using Best Parameters

# %%
rfc=RandomForestClassifier(criterion="gini",max_depth=None,max_features="sqrt",n_estimators=50)
rfc.fit(x_train,y_train)
score=cross_val_score(rfc,x,y,cv=10,scoring="accuracy").mean()
score
# Out:
# 0.856537378792618

# %% [markdown]
# ### Saving Model

# %%
import joblib
joblib.dump(rfc,"Model_Hr_Analytics_rfc.csv")
# Out:
# ['Model_Hr_Analytics_rfc.csv']

# %% [markdown]
# ### Loading Model

# %%
Model_Hr_Analytics=joblib.load("Model_Hr_Analytics_rfc.csv")

# %% [markdown]
# ### Using Model

# %%
pd.DataFrame(Model_Hr_Analytics.predict(x_test))
# Out:
#      0
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# ..  ..
# 273  0
# 274  0
# 275  0
# 276  0
# 277  0
#
# [278 rows x 1 columns]
