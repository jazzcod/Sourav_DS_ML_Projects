# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
#reading data
ds_happy=pd.read_csv("Happiness.csv")
ds_happy
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# ### Defining Variables Information

# %%
#describing the various information related to the data 
ds_happy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# ### Finding Null Values

# %%
#finding id there are null values
ds_happy.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
#plotting null values in heatmap
sns.heatmap(ds_happy.isnull())

# %% [markdown]
# ### Describing Statistics

# %%
#describing the different statistics related to the data
ds_happy.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# ### Plottng Correlation

# %%
#describing the correlation matrix
ds_happy.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
#describing the correlation in a heatmap
corr_hmap=ds_happy.corr()
plt.figure(figsize=(9,9))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %% [markdown]
# From the above heatmap it can be infered that a lot of factors are positively co-related to the Happiness Score. GDP is the most important factor followed by family, health, freedom, trust and so on. Generosity being the least co0related to the Happiness Score.

# %% [markdown]
# ### Univariate Analysis

# %%
#finding the counts of the countries according to the region
ds_happy["Region"].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
#plotting the counts of the countries according to the region
plt.figure(figsize=(28,9))
ax=sns.countplot(x="Region",data=ds_happy)
ax.set_title("Number of countries in different regions",fontsize=20)
plt.xlabel("Region",fontsize=17)
plt.ylabel("Count", fontsize=17)
# Out:
# Text(0, 0.5, 'Count')

# %%
#clustering the happiestcountries according to the Happiness Score
happy_filter=ds_happy['Happiness Score']>=6.5
happy_countries=ds_happy[happy_filter]
happy=happy_countries.Region.value_counts()
happy
# Out:
# Western Europe                     14
# Latin America and Caribbean         7
# Middle East and Northern Africa     4
# North America                       2
# Australia and New Zealand           2
# Central and Eastern Europe          1
# Southeastern Asia                   1
# Name: Region, dtype: int64

# %%
#plotting the happiest contries according to the happiest score and by region
labels=happy_countries.Region.value_counts().index
colors=["purple","blue","red","yellow","green","orange","coral"]
explode=[0,0,0,0,0,0,0]
sizes=happy_countries.Region.value_counts().values
plt.figure(figsize=(7,7))
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct="%1.1f%%")
plt.title("Distribution of the Happiest Countries by Region",color="black",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Distribution of the Happiest Countries by Region')

# %%
#clustering the unhappiest countries according to the Happiness Score
unhappy_filter=ds_happy['Happiness Score']<4.5
unhappy_countries=ds_happy[unhappy_filter]
unhappy=unhappy_countries.Region.value_counts()
unhappy
# Out:
# Sub-Saharan Africa                 25
# Middle East and Northern Africa     3
# Central and Eastern Europe          3
# Southern Asia                       2
# Southeastern Asia                   2
# Name: Region, dtype: int64

# %%
#plotting the unhappiest contries according to the happiest score and by region
labels=unhappy_countries.Region.value_counts().index
colors=["green","blue","red","yellow","orange"]
explode=[0,0,0,0,0]
sizes=unhappy_countries.Region.value_counts().values
plt.figure(figsize=(7,7))
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct="%1.1f%%")
plt.title("Distribution of the Unhappy Countries by Region",color="black",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Distribution of the Unhappy Countries by Region')

# %% [markdown]
# ### Bivariate Analysis

# %%
#relation of Happiness Score with GDP
sns.scatterplot(x=ds_happy["Happiness Score"],y=ds_happy["Economy (GDP per Capita)"],data=ds_happy)
plt.show()

# %%
#relation of Happiness Score with Family
sns.scatterplot(x=ds_happy["Happiness Score"],y=ds_happy["Family"],data=ds_happy)
plt.show()

# %%
#relation of Happiness Score Health
sns.scatterplot(x=ds_happy["Happiness Score"],y=ds_happy["Health (Life Expectancy)"],data=ds_happy)
plt.show()

# %%
#relation of Happiness Score with Freedom
sns.scatterplot(x=ds_happy["Happiness Score"],y=ds_happy["Freedom"],data=ds_happy)
plt.show()

# %%
#relation of Happiness Score with Government Corruption
sns.scatterplot(x=ds_happy["Happiness Score"],y=ds_happy["Trust (Government Corruption)"],data=ds_happy)
plt.show()

# %%
#relation of Happiness Score with Generosity
sns.scatterplot(x=ds_happy["Happiness Score"],y=ds_happy["Generosity"],data=ds_happy)
plt.show()

# %%
#relation of Happiness Score with Region
sns.barplot(x=ds_happy["Happiness Score"],y=ds_happy["Region"],data=ds_happy)
plt.show()

# %%
#relation of GDP with Region
sns.barplot(x=ds_happy["Economy (GDP per Capita)"],y=ds_happy["Region"],data=ds_happy)
plt.show()

# %%
#relation of Family with Region
sns.barplot(x=ds_happy["Family"],y=ds_happy["Region"],data=ds_happy)
plt.show()

# %%
#relation of Health with Region
sns.barplot(x=ds_happy["Health (Life Expectancy)"],y=ds_happy["Region"],data=ds_happy)
plt.show()

# %%
#relation of Freedom with Region
sns.barplot(x=ds_happy["Freedom"],y=ds_happy["Region"],data=ds_happy)
plt.show()

# %%
#relation of Trust with Region
sns.barplot(x=ds_happy["Trust (Government Corruption)"],y=ds_happy["Region"],data=ds_happy)
plt.show()

# %%
#relation of Generosity with Region
sns.barplot(x=ds_happy["Generosity"],y=ds_happy["Region"],data=ds_happy)
plt.show()

# %%
#relation of all the variables with each other on a pairplot
sns.pairplot(ds_happy)

# %% [markdown]
# ### Dropping Columns

# %%
#dropping all the unnecessary columns that will not be taken to the model 
cols=["Country","Region","Happiness Rank","Standard Error"]
ds_happy=ds_happy.drop(cols,axis=1)
ds_happy
# Out:
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# 2              7.527                   1.32548  1.36058
# 3              7.522                   1.45900  1.33095
# 4              7.427                   1.32629  1.32261
# ..               ...                       ...      ...
# 153            3.465                   0.22208  0.77370
# 154            3.340                   0.28665  0.35386
# 155            3.006                   0.66320  0.47489
# 156            2.905                   0.01530  0.41587
# 157            2.839                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %% [markdown]
# ###  Plotting Outliers

# %%
#plotting he variables in a box pot to find outliers
ds_happy.plot(kind="box",subplots=True,layout=(2,5))
# Out:
# Happiness Score                     AxesSubplot(0.125,0.536818;0.133621x0.343182)
# Economy (GDP per Capita)         AxesSubplot(0.285345,0.536818;0.133621x0.343182)
# Family                            AxesSubplot(0.44569,0.536818;0.133621x0.343182)
# Health (Life Expectancy)         AxesSubplot(0.606034,0.536818;0.133621x0.343182)
# Freedom                          AxesSubplot(0.766379,0.536818;0.133621x0.343182)
# Trust (Government Corruption)          AxesSubplot(0.125,0.125;0.133621x0.343182)
# Generosity                          AxesSubplot(0.285345,0.125;0.133621x0.343182)
# Dystopia Residual                    AxesSubplot(0.44569,0.125;0.133621x0.343182)
# dtype: object

# %% [markdown]
# ### Removing Outliers

# %%
#using z-score to remove the outliers from the variables
from scipy.stats import zscore
z_score=abs(zscore(ds_happy))
print(ds_happy.shape)
ds_happy_final=ds_happy.loc[(z_score<3).all(axis=1)]
print(ds_happy_final.shape)
# Out:
# (158, 8)
# (152, 8)

# %% [markdown]
# ### Plotting Distribution

# %%
#plotting the distribution of the variables to check skewness
for i in ds_happy_final.columns:
    plt.figure()
    sns.distplot(ds_happy_final[i])

# %% [markdown]
# ### Checking Skewness

# %%
#checking skewness of the variables
ds_happy_final.skew()
# Out:
# Happiness Score                  0.165587
# Economy (GDP per Capita)        -0.401110
# Family                          -0.815356
# Health (Life Expectancy)        -0.733453
# Freedom                         -0.406211
# Trust (Government Corruption)    1.287270
# Generosity                       0.646579
# Dystopia Residual               -0.045578
# dtype: float64

# %% [markdown]
# ### Log Transformation

# %%
#log transformation to make the skewed variables to a normally distributed data.
for col in ds_happy_final:                  
    if ds_happy_final.skew().loc[col]>.55:
        ds_happy_final[col]=np.log1p(ds_happy_final[col])

# %% [markdown]
# ### Replotting Distribution

# %%
#replotting the distribution after lof transformation 
for i in ds_happy_final.columns:
    plt.figure()
    sns.distplot(ds_happy_final[i])

# %% [markdown]
# ### Rechecking Skewness

# %%
#rechecking skewness after after transformation
ds_happy_final.skew()
# Out:
# Happiness Score                  0.165587
# Economy (GDP per Capita)        -0.401110
# Family                          -0.815356
# Health (Life Expectancy)        -0.733453
# Freedom                         -0.406211
# Trust (Government Corruption)    1.108599
# Generosity                       0.422071
# Dystopia Residual               -0.045578
# dtype: float64

# %% [markdown]
# ### Seperating Target and Input Variable

# %%
#sepating the dataframe into dependent and independent variable these are the independent variables
x=ds_happy_final.iloc[:,[1,2,3,4,5,6]]
x
# Out:
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 150                   0.46534  0.77115                   0.15185  0.46866
# 151                   0.25812  0.85188                   0.27125  0.39493
# 152                   0.31982  0.30285                   0.30335  0.23414
# 154                   0.28665  0.35386                   0.31910  0.48450
# 156                   0.01530  0.41587                   0.22396  0.11850
#
#      Trust (Government Corruption)  Generosity
# ...

# %%
#sepating the dataframe into dependent and independent variable this is the dependent variable
y=ds_happy_final.iloc[:,0]
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 150    3.655
# 151    3.587
# 152    3.575
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 152, dtype: float64

# %% [markdown]
# ### Scaling Data

# %%
#scaling the input varibale
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.38120592e+00,  1.36173566e+00,  1.24883532e+00,
#          1.58646238e+00,  2.39565125e+00,  5.91358453e-01],
#        [ 1.13920813e+00,  1.57273597e+00,  1.27511639e+00,
#          1.34083622e+00,  7.83424844e-02,  1.67583434e+00],
#        [ 1.19871199e+00,  1.40604092e+00,  9.74995582e-01,
#          1.47840022e+00,  2.86239359e+00,  9.50304307e-01],
#        [ 1.54175845e+00,  1.28745330e+00,  1.01833270e+00,
#          1.61422882e+00,  1.97801460e+00,  9.94517929e-01],
#        [ 1.20079309e+00,  1.25407427e+00,  1.10205493e+00,
#          1.36886964e+00,  1.69848772e+00,  1.83577612e+00],
#        [ 1.10819726e+00,  1.23666434e+00,  1.03432274e+00,
#          1.42707236e+00,  2.35022529e+00,  6.05031363e-02],
#        [ 1.20888623e+00,  1.08421742e+00,  1.04961578e+00,
#          1.25399936e+00,  1.60679547e+00,  1.96591394e+00],
#        [ 1.21471843e+00,  1.11983773e+00,  1.12353898e+00,
#          1.54794980e+00,  2.53431925e+00,  1.11695561e+00],
# ...

# %% [markdown]
# ### Importing Regression Algorithims and Metrices

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Putting Aliases

# %%
LR=LinearRegression()
LA=Lasso()
RI=Ridge(alpha=2)
EN=ElasticNet()
KNR=KNeighborsRegressor()
DTR=DecisionTreeRegressor(random_state=63)
ABR=AdaBoostRegressor(random_state=63)
RFR=RandomForestRegressor(random_state=63)
GBR=GradientBoostingRegressor(random_state=63)

# %% [markdown]
# ### Appending Models

# %%
models=[]
models.append(('LinearRegression',LR))
models.append(('Lasso',LA))
models.append(('Ridge',RI))
models.append(('ElasticNet',EN))
models.append(('DecisionTreeRegressor',DTR))
models.append(('KNeighborsRegressor',KNR))
models.append(('AdaBoostRegressor',ABR))
models.append(('RandomForestRegressor',RFR))
models.append(('GradientBoostingRegressor',GBR))

# %% [markdown]
# ### Machine Learning

# %%
Model=[]
R2_score=[]
cvs=[]
MSE=[]
for name,model in models:
    print('*********************************',name,'*********************************')
    print('\n',model)
    Model.append(name)
    model.fit(x_train,y_train)
    pre=model.predict(x_test)
    r2=r2_score(y_test,pre)
    print('R2_score = ',r2)
    R2_score.append(r2)
    mse=mean_squared_error(y_test,pre)
    print("Mean_Squared_Error =",mse)
    MSE.append(round(mse,3))
    score= cross_val_score(model,x,y,cv=10,scoring='r2').mean()
    print('Cross_Val_Score = ',score)
    cvs.append(round(score,3))
    print('\n')
# Out:
# ********************************* LinearRegression *********************************
#
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# R2_score =  0.8949169009661215
# Mean_Squared_Error = 0.12092639214665271
# Cross_Val_Score =  -28.794661647327484
#
#
# ********************************* Lasso *********************************
#
#  Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)
# R2_score =  -0.009122094756315091
# Mean_Squared_Error = 1.1612666097239084
# Cross_Val_Score =  -74.6964896754963
#
#
# ********************************* Ridge *********************************
#
#  Ridge(alpha=2, copy_X=True, fit_intercept=True, max_iter=None, normalize=False,
#       random_state=None, solver='auto', tol=0.001)
# R2_score =  0.8952318046672597
# Mean_Squared_Error = 0.12056401067139759
# ...

# %% [markdown]
# ### Algorithim Compare Table

# %%
#structuring the compare DataFrame
result = pd.DataFrame({'Model': Model, 'R2_score': R2_score ,'Mean_Squared_Error' :MSE,'Cross_val_score':cvs})
result
# Out:
#                        Model  R2_score  Mean_Squared_Error  Cross_val_score
# 0           LinearRegression  0.894917               0.121          -28.795
# 1                      Lasso -0.009122               1.161          -74.696
# 2                      Ridge  0.895232               0.121          -28.554
# 3                 ElasticNet  0.433071               0.652          -49.463
# 4      DecisionTreeRegressor  0.539678               0.530          -69.276
# 5        KNeighborsRegressor  0.820386               0.207          -38.011
# 6          AdaBoostRegressor  0.821311               0.206          -35.419
# 7      RandomForestRegressor  0.808968               0.220          -31.312
# 8  GradientBoostingRegressor  0.790146               0.241          -37.447

# %% [markdown]
# ### Generating Best Random State for Ridge Algorithim

# %%
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=.20)
    RI.fit(x_train,y_train)
    y_pred=RI.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print("r2_score corresponding to random_state:",r_state,"is:",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr    
        final_r_state=r_state
print()
print()
print("max r2_score corresponding to",final_r_state,"is",max_r_score)
# Out:
# r2_score corresponding to random_state: 42 is: 0.7032697312443774
# r2_score corresponding to random_state: 43 is: 0.8021605610999166
# r2_score corresponding to random_state: 44 is: 0.8283677091753092
# r2_score corresponding to random_state: 45 is: 0.8617647979820134
# r2_score corresponding to random_state: 46 is: 0.6826820663153121
# r2_score corresponding to random_state: 47 is: 0.8109219306886073
# r2_score corresponding to random_state: 48 is: 0.7498729470440115
# r2_score corresponding to random_state: 49 is: 0.7087295735732989
# r2_score corresponding to random_state: 50 is: 0.8950914013433289
# r2_score corresponding to random_state: 51 is: 0.6963483554458757
# r2_score corresponding to random_state: 52 is: 0.8132952663967532
# r2_score corresponding to random_state: 53 is: 0.6202102632785924
# r2_score corresponding to random_state: 54 is: 0.7487112237347155
# r2_score corresponding to random_state: 55 is: 0.781866404485458
# ...

# %% [markdown]
# ### Retesting Using Best Random State

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=50,test_size=.20)
RI.fit(x_train,y_train)
y_pred=RI.predict(x_test)
print("r2 score is :",(r2_score(y_test,y_pred)))
print("RMSE is :",np.sqrt(mean_squared_error(y_test,y_pred)))
print("Mean_Absolute_Error is :",mean_absolute_error(y_test,y_pred))
# Out:
# r2 score is : 0.8952318046672597
# RMSE is : 0.34722328647629264
# Mean_Absolute_Error is : 0.25787655706596296

# %% [markdown]
# ### Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
parameterRI={'alpha':[200,230,250,265,270,275,290,300,500]}
gridRI=GridSearchCV(RI,param_grid=parameterRI,n_jobs=-1,cv=10)
gridRI.fit(x_train,y_train)
gridRI.best_score_,gridRI.best_params_
# Out:
# (0.6076526800010866, {'alpha': 200})

# %% [markdown]
# I have used alpha=2 in my Ridge parameter and it has improved the R2 score

# %%
#we will be finalizing the Ridge model as it is has the highest R2 Score

# %% [markdown]
# ### Saving the Model

# %%
import joblib
joblib.dump(RI,"Model_World_Happiness_RI.csv")
# Out:
# ['Model_World_Happiness_RI.csv']

# %% [markdown]
# ### Loading Model

# %%
Model_World_Happiness=joblib.load("Model_World_Happiness_RI.csv")

# %% [markdown]
# ### Using Model

# %%
Model_World_Happiness.predict(x_test)
# Out:
# array([5.93381664, 5.34672442, 7.06497977, 7.14724784, 3.55677201,
#        4.73072366, 3.85954537, 7.08139118, 6.83555839, 5.84085516,
#        5.88306216, 5.66438198, 6.40562287, 4.3860176 , 5.93942851,
#        6.83949574, 4.08499377, 4.2420548 , 4.0020081 , 5.21761102,
#        5.52595769, 5.23440619, 6.68921617, 5.24012853, 4.48889629,
#        5.12960324, 6.03089452, 5.95384009, 4.91555496, 3.77384219,
#        5.51212664])
