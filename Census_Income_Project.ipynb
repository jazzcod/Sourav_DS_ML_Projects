# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
ds_census=pd.read_csv("Census.csv")
ds_census
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
#dropping columns
ds_census.drop("Unnamed: 15",inplace=True,axis=1)

# %%
ds_census
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
#replacing NaN values
ds_census=ds_census.replace("?",np.nan)
ds_census
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90       NaN   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66       NaN  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
#label encodibng target variable
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
ds_census["income"]=le.fit_transform(ds_census["income"].astype(str))
ds_census
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90       NaN   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66       NaN  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
ds_census.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %%
#replacing missing values
for col in ["workclass","occupation","native.country"]:
    ds_census[col].fillna(ds_census[col].mode()[0],inplace=True)

# %%
ds_census.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
#calling unique objects
for column in ds_census.columns:
    if ds_census[column].dtype==object:
        print(str(column)+":"+str(ds_census[column].unique()))
        print(ds_census[column].value_counts())
        print("************************************************")
        print("\n")
# Out:
# workclass:['Private' 'State-gov' 'Federal-gov' 'Self-emp-not-inc' 'Self-emp-inc'
#  'Local-gov' 'Without-pay' 'Never-worked']
# Private             24532
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
# ************************************************
#
#
# education:['HS-grad' 'Some-college' '7th-8th' '10th' 'Doctorate' 'Prof-school'
#  'Bachelors' 'Masters' '11th' 'Assoc-acdm' 'Assoc-voc' '1st-4th' '5th-6th'
#  '12th' '9th' 'Preschool']
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# ...

# %%
ds_census.corr()
# Out:
#                      age    fnlwgt  education.num  capital.gain  capital.loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education.num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital.gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital.loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours.per.week  0.068756 -0.018768       0.148123      0.078409      0.054256
# income          0.234037 -0.009463       0.335154      0.223329      0.150526
#
#                 hours.per.week    income
# age                   0.068756  0.234037
# fnlwgt               -0.018768 -0.009463
# education.num         0.148123  0.335154
# capital.gain          0.078409  0.223329
# capital.loss          0.054256  0.150526
# hours.per.week        1.000000  0.229689
# income                0.229689  1.000000

# %%
#plotting correlation in a heatmap.
corr_hmap=ds_census.corr()
plt.figure(figsize=(6,6))
sns.heatmap(corr_hmap,annot=True,fmt=".0%",cmap="Blues")
plt.show()

# %% [markdown]
# ### Making Correlation Graph

# %%
plt.figure(figsize=(8,6))
ds_census.drop("income",axis=1).corrwith(ds_census["income"]).plot(kind="bar",grid=True)
plt.xticks(rotation=20)
plt.title("Correlation wih target variable")
# Out:
# Text(0.5, 1.0, 'Correlation wih target variable')

# %% [markdown]
# ### Univariate Analysis

# %%
sns.countplot(x="income",data=ds_census)
plt.xlabel("0= <=50K and 1= >50K")
print(ds_census.income.value_counts())
# Out:
# 0    24720
# 1     7841
# Name: income, dtype: int64

# %%
#checking mean of tghe age group
ages=ds_census["age"].hist(bins=max(ds_census["age"]-min(ds_census["age"])))
mean_val=np.mean(ds_census["age"])
plt.axvline(mean_val,linewidth=4,color="red",label="mean age")
plt.xlabel("age")
plt.ylabel("count")
plt.legend()
plt.show()

# %%
#checking number of hours  per week
ds_census["hours.per.week"].hist()
plt.xlabel("hours per week")
plt.ylabel("count")
plt.title("people workiong number of hours per week")
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
facet=sns.FacetGrid(ds_census,col="income")
facet.map(sns.distplot,"age")
plt.show()

# %%
#sex vs income
sns.countplot(x="sex",hue="income",data=ds_census)
plt.title("Salary Count according to Sex")
plt.xlabel("0= <=50k and 1= >50k")
plt.ylabel("Counting of People")
plt.show()

# %%
#plotting probability
sns.factorplot(x="sex",y="income",data=ds_census)
plt.title("Salary Count according to Sex")
plt.xlabel("0= <=50k and 1= >50k")
plt.ylabel("Counting of People")
plt.show()

# %%
#plotting probability
sns.factorplot(x="education",y="income",data=ds_census,kind="bar",palette="muted",aspect=3,size=5)
plt.title("Salary Count according to Sex")
plt.xlabel("0= <=50k and 1= >50k")
plt.ylabel("Counting of People")
plt.show()

# %%
#workclass vs income
plt.figure(figsize=(12,6))
sns.countplot(x="workclass",hue="income",data=ds_census)
plt.title("Salary Count according to workclass")
plt.xlabel("0= <=50k and 1= >50k")
plt.ylabel("Counting of People")
plt.show()

print(ds_census.groupby("workclass")["income"].value_counts())
# Out:
# workclass         income
# Federal-gov       0           589
#                   1           371
# Local-gov         0          1476
#                   1           617
# Never-worked      0             7
# Private           0         19378
#                   1          5154
# Self-emp-inc      1           622
#                   0           494
# Self-emp-not-inc  0          1817
#                   1           724
# State-gov         0           945
#                   1           353
# Without-pay       0            14
# Name: income, dtype: int64

# %%
ds_census.skew()
# Out:
# age                0.558743
# fnlwgt             1.446980
# education.num     -0.311676
# capital.gain      11.953848
# capital.loss       4.594629
# hours.per.week     0.227643
# income             1.212430
# dtype: float64

# %%
#fixing skewness by squareroot and cube root method
ds_census.skew()
for col in ds_census.skew().index:
    if col in ds_census.describe().columns:
        if ds_census[col].skew()>0.55:
            ds_census[col]=np.sqrt(ds_census[col])
        if ds_census[col].skew()<-0.55:
            ds_census[col]=npcbrt(ds_census[col])

# %%
ds_census.skew()
# Out:
# age               0.204327
# fnlwgt            0.189115
# education.num    -0.311676
# capital.gain      5.894582
# capital.loss      4.376357
# hours.per.week    0.227643
# income            1.212430
# dtype: float64

# %%
#label encoding
for column in ds_census.columns:
    if ds_census[column].dtypes==np.number:
        continue
    ds_census[column]=le.fit_transform(ds_census[column])

# %%
ds_census
# Out:
#             age  workclass      fnlwgt  education  education.num  \
# 0      9.486833          3  277.584221         11              8
# 1      9.055385          3  364.513374         11              8
# 2      8.124038          3  431.347887         15              9
# 3      7.348469          3  374.645165          5              3
# 4      6.403124          3  514.454080         15              9
# ...         ...        ...         ...        ...            ...
# 32556  4.690416          3  556.912920         15              9
# 32557  5.196152          3  507.249446          7             11
# 32558  6.324555          3  392.904569         11              8
# 32559  7.615773          3  389.756334         11              8
# 32560  4.690416          3  448.876375         11              8
#
#        marital.status  occupation  relationship  race  sex  capital.gain  \
# 0                   6           9             1     4    0           0.0
# ...

# %%
#plotting outliers
for i in ds_census.columns:
    plt.figure()
    sns.boxplot(ds_census[i])
